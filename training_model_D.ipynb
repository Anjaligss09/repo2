# %% [markdown]
# # **Project #4 - Food Recognition**
# ### Deep Learning course - A.Y. 2020-2021
# Students:
#
# - Giuseppe	Murro	(0000997317 $-$ giuseppe.murro@studio.unibo.it)
# - Salvatore	Pisciotta	(0000985203 $-$ salvatore.pisciotta2@studio.unibo.it)

# %% [markdown]
# ## ***TRAINING MODEL D***

# %% [markdown]
# ### Preliminary settings
# Check if the runtime is on Colab

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %% [markdown]
# Install extern libraries if they are not installed

# %%
# !pip install segmentation_models

# %% [markdown]
# Clone the repo in order to access to the dataset if the runtime is on Colab

# %%
if IN_COLAB:
    # !git clone https://github.com/gmurro/FoodRecognition.git
    # %cd /content/FoodRecognition/src
    SRC_PATH = ""
else:
    # Add path of the SRC folder in order to import custom libraries
    import sys
    SRC_PATH = "../../"
    sys.path.insert(1, SRC_PATH)

# %% [markdown]
# Import useful libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import os
from PIL import Image

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

from utils import segmentation_utils

# %env SM_FRAMEWORK = tf.keras
import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# ### Data acquisition
# Define the categories of food on which we want train the segmentation model

# %%
cat_names = ['water'
             , 'bread-white'
             , 'salad-leaf-salad-green'
             , 'tomato'
             , 'butter'
             , 'carrot'
             , 'coffee-with-caffeine'
             , 'rice'
             , 'egg'
             , 'mixed-vegetables'
             , 'wine-red'
             , 'apple'
             , 'jam'
             , 'potatoes-steamed'
             , 'banana'
             , 'cheese' ]
             
batch_size = 64
img_size = (128,128)
num_classes = len(cat_names) + 1
num_filters = 32

# %% [markdown]
# Define the class `DataGenerator`, which will be used for real-time data feeding to our Keras model.
# We make the latter inherit the properties of `keras.utils.Sequence` so that we can leverage nice functionalities such as *multiprocessing*.

# %%
class DataGenerator(tf.keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, coco, batch_size, img_size, img_ids, img_paths, cat_to_class, aug_args=None, shuffle=True):
        self.coco = coco
        self.batch_size = batch_size
        self.img_size = img_size
        self.img_paths = img_paths
        self.img_ids = img_ids
        self.cat_to_class = cat_to_class
        self.aug_args = aug_args
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        """ Number of batches per epoch """
        return len(self.img_ids) // self.batch_size

    def __getitem__(self, idx):
        """ Generate one batch of data """

        # Generate indexes of the batch
        indexes = self.indexes[idx * self.batch_size:(idx + 1) * self.batch_size]

        # n of categories
        n_cat = len(self.cat_to_class)

        # Find list of img paths and image ids to read in the batch
        batch_img_paths = [self.img_paths[i] for i in indexes]
        batch_img_ids = [self.img_ids[i] for i in indexes]

        # load imgs
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype=np.float32)
        for j, path in enumerate(batch_img_paths):
            img = img_to_array(load_img(path, target_size=self.img_size))
            x[j] = img

        # load masks
        y = np.zeros((self.batch_size,) + self.img_size + (n_cat,), dtype=np.float32)
        for j, img_id in enumerate(batch_img_ids):
            mask = segmentation_utils.load_mask(self.coco, img_id, self.cat_to_class)

            # scale down mask
            mask_scaled = np.zeros(self.img_size+ (n_cat,), dtype=np.uint8)
            for i in range(n_cat):
                mask_scaled[:,:,i] = Image.fromarray(mask[:,:,i]).resize(self.img_size, Image.NEAREST)

            y[j] = np.array(mask_scaled, dtype=np.float32)
            
        if self.aug_args is not None:
            x, y = segmentation_utils.augment(x, y, self.aug_args)
            
            #
            
        return x, y

    def on_epoch_end(self):
        """ Method called at the end of every epoch that updates indexes """
        self.indexes = np.arange(len(self.img_ids))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

# %% [markdown]
# Show some examples of images from the validation set

# %%
# @title Show some images
path_dir = SRC_PATH+"../data/val/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

# load all data
x, y = segmentation_utils.load_data(coco, path_dir+"images/", img_size, cat_names)
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# Loading images:
# 550/554 [============================>.] - ETA: 0s
# Loading masks:
# 552/554 [============================>.] - ETA: 0s

# %%
# show 3 random image and compare with augmentation
n = 3

# parameters for the augmetation
aug_args = dict(
                  rotation_range=5              # @param {type:"slider", min:0, max:10, step:1}
                , width_shift_range=0.01        # @param {type:"slider", min:0, max:0.1, step:0.01}
                , height_shift_range=0.01       # @param {type:"slider", min:0, max:0.1, step:0.01}
                , brightness_range=(0.8, 1.2)  
                , shear_range=0.01              # @param {type:"slider", min:0, max:0.1, step:0.01}
                , zoom_range=[0.7, 1]           
                , horizontal_flip=True          # @param {type:"boolean"} 
                , vertical_flip=True            # @param {type:"boolean"} 
                , fill_mode='constant'          #@param ["constant", "nearest", "reflect", "wrap"] {type:"raw"}
                , data_format='channels_last')

idx = random.randint(0, len(x)-1-n)

for i in range(idx,idx+n):
    print("\nImage {}".format(i))

    # show image not augmented
    segmentation_utils.show_mask(x[i,:,:]/255, y[i,:,:,:], cat_names)

    # show the same image augmented
    x_p = x[i].reshape((1,)+x[i].shape)
    y_p = y[i].reshape((1,)+y[i].shape)
    x_aug, y_aug = segmentation_utils.augment(x_p, y_p, aug_args)
    segmentation_utils.show_mask(x_aug[0,:,:]/255, y_aug[0,:,:,:], cat_names)
# Out:
# Image 4
# Image 5
# Image 6

# %% [markdown]
# Instantiate Data Generators for training set

# %%
# @title DataGenerator from training set
path_dir = SRC_PATH+"../data/train/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

# compute the class weights
class_dist = segmentation_utils.get_class_dist(coco, cat_names)
class_weights = segmentation_utils.get_class_weights(class_dist)

img_paths = [os.path.join(path_dir+"images/", file_name) for file_name in img_names]

# parameters for the augmetation
aug_args = dict(
                  rotation_range=5              # @param {type:"slider", min:0, max:10, step:1}
                , width_shift_range=0.01        # @param {type:"slider", min:0, max:0.1, step:0.01}
                , height_shift_range=0.01       # @param {type:"slider", min:0, max:0.1, step:0.01}
                , brightness_range=(0.8, 1.2)  
                , shear_range=0.01              # @param {type:"slider", min:0, max:0.1, step:0.01}
                , zoom_range=[0.7, 1]           
                , horizontal_flip=True          # @param {type:"boolean"} 
                , vertical_flip=True            # @param {type:"boolean"} 
                , fill_mode='constant'          #@param ["constant", "nearest", "reflect", "wrap"] {type:"raw"}
                , data_format='channels_last')

# create the generator
train_gen = DataGenerator(coco, batch_size, img_size, img_ids, img_paths,  cat_to_class, aug_args)
# Out:
# loading annotations into memory...
# Done (t=1.88s)
# creating index...
# index created!

# %% [markdown]
# Show class distribution and class weights from the training set. Class weights are computed according to the following formula:
#
# $w(y) = \frac{n\_samples}{n\_classes \cdot counts(y)}$

# %%
# print class weights
print("CLASS WEIGHTS:")
for i, weight in enumerate(class_weights):
    print("\t- {}: {:.2f}".format(cat_names[i],weight))
    
# plot a pie chart of the class distribution
segmentation_utils.plot_class_dist(class_dist, cat_names, cat_to_class, without_background=True)
# Out:
# CLASS WEIGHTS:
# 	- background: 0.06
# 	- water: 0.35
# 	- egg: 1.02
# 	- butter: 0.63
# 	- bread-white: 0.50
# 	- jam: 1.27
# 	- apple: 1.26
# 	- cheese: 1.58
# 	- carrot: 0.71
# 	- salad-leaf-salad-green: 0.54
# 	- banana: 1.54
# 	- mixed-vegetables: 1.02
# 	- tomato: 0.60
# 	- wine-red: 1.17
# 	- rice: 0.97
# 	- coffee-with-caffeine: 0.73
# 	- potatoes-steamed: 1.41

# %% [markdown]
# Instantiate Data Generators for validation set

# %%
# @title DataGenerator from validation set
path_dir = SRC_PATH+"../data/val/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

img_paths = [os.path.join(path_dir+"images/", file_name) for file_name in img_names]

# create the generator
val_gen = DataGenerator(coco, batch_size, img_size, img_ids, img_paths, cat_to_class)
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!

# %% [markdown]
# ### Model architecture
# Eff U-Net

# %%
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB5

def conv_block(input, num_filters, size=3, padding='same', initializer="he_normal"):
    x = layers.Conv2D(filters=num_filters, kernel_size=(size, size), padding=padding, kernel_initializer=initializer)(input)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2D(filters=num_filters, kernel_size=(size, size), padding=padding, kernel_initializer=initializer)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    return x


def deconv_block(input, num_filters, skip_features, size=2, padding='same', strides=(2, 2)):
    x = layers.Conv2DTranspose(num_filters, kernel_size=(size, size), strides=strides, padding=padding)(input)
    x = layers.concatenate([x, skip_features], axis=3)
    x = conv_block(x, num_filters)
    return x

def eff_unet(img_size, num_classes):
    
    ''' Input layer '''
    input_layer = layers.Input(shape=img_size + (3,), name='image_input')
    
    """ Pre-trained EfficientNetB5 Model """
    efficientnetb5 = EfficientNetB5(include_top=False, weights="imagenet", input_tensor=input_layer)
    for layer in efficientnetb5.layers:
        layer.trainable = False
    
    """ Encoder """
    s1 = efficientnetb5.get_layer("block2a_expand_activation").input
    s2 = efficientnetb5.get_layer("block3a_expand_activation").output
    s3 = efficientnetb5.get_layer("block4a_expand_activation").output
    s4 = efficientnetb5.get_layer("block6a_expand_activation").output

    """ Bottleneck """
    b1 = efficientnetb5.get_layer("top_activation").output
    
    """ Decoder """
    d1 = deconv_block(input=b1, num_filters=512, skip_features=s4)
    d2 = deconv_block(input=d1, num_filters=256, skip_features=s3)
    d3 = deconv_block(input=d2, num_filters=128, skip_features=s2)
    d4 = deconv_block(input=d3, num_filters=64,  skip_features=s1)

    """ Last Upsampler """
    x = layers.Conv2DTranspose(32, (2, 2), strides=2, padding="same")(d4)
    x = conv_block(x, 32)

    """ Output """
    # output: add a per-pixel classification layer
    output_layer = layers.Conv2D(filters=num_classes, kernel_size=(1, 1), activation="sigmoid", padding="same")(x)

    # Define the model
    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='EfficientNetB5_U-Net')
    return model
    

# Free up RAM in case the model definition cells were run multiple times
tf.keras.backend.clear_session()

# Build model
model = eff_unet(img_size, num_classes)
model.summary()
# Out:
# Model: "EfficientNetB5_U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image_input (InputLayer)        [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 128, 128, 3)  0           image_input[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 128, 128, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 129, 129, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 64, 64, 48)   1296        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 64, 64, 48)   192         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 64, 64, 48)   0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 64, 64, 48)   432         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 64, 64, 48)   192         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 64, 64, 48)   0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 48)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 48)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 12)     588         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 48)     624         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 64, 64, 48)   0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 64, 64, 24)   1152        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 64, 64, 24)   96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 64, 64, 24)   216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 64, 64, 24)   96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 64, 64, 24)   0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 64, 64, 24)   0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 64, 64, 24)   576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 64, 64, 24)   96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 64, 64, 24)   0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 64, 64, 24)   0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 64, 64, 24)   216         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 64, 64, 24)   96          block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 64, 64, 24)   0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 24)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 64, 64, 24)   0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 64, 64, 24)   576         block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 64, 64, 24)   96          block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 64, 64, 24)   0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 64, 64, 24)   0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 64, 64, 144)  3456        block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 64, 64, 144)  576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 64, 64, 144)  0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 65, 65, 144)  0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 32, 32, 144)  1296        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 32, 32, 144)  576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 32, 32, 144)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 32, 32, 144)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 32, 32, 40)   5760        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 32, 32, 40)   160         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 32, 32, 240)  9600        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 32, 32, 240)  960         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 32, 32, 240)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 32, 32, 240)  2160        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 32, 32, 240)  960         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 32, 32, 240)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 240)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 32, 32, 240)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 32, 32, 40)   9600        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 32, 32, 40)   160         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 32, 32, 40)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 32, 32, 40)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 32, 32, 240)  9600        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 32, 32, 240)  960         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 32, 32, 240)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 32, 32, 240)  2160        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 32, 32, 240)  960         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 32, 32, 240)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 240)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 32, 32, 240)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 32, 32, 40)   9600        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 32, 32, 40)   160         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 32, 32, 40)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 32, 32, 40)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 32, 32, 240)  9600        block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 32, 32, 240)  960         block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 32, 32, 240)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 32, 32, 240)  2160        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 32, 32, 240)  960         block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 32, 32, 240)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 240)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 32, 32, 240)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 32, 32, 40)   9600        block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 32, 32, 40)   160         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 32, 32, 40)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 32, 32, 40)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 32, 32, 240)  9600        block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 32, 32, 240)  960         block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 32, 32, 240)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 32, 32, 240)  2160        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 32, 32, 240)  960         block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 32, 32, 240)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 240)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 32, 32, 240)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 32, 32, 40)   9600        block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 32, 32, 40)   160         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 32, 32, 40)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 32, 32, 40)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 32, 32, 240)  9600        block2e_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 32, 32, 240)  960         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 32, 32, 240)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 35, 35, 240)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 16, 16, 240)  6000        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 16, 16, 240)  960         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 16, 16, 240)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 240)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 16, 16, 240)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 16, 16, 64)   15360       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 16, 16, 64)   256         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 16, 16, 384)  24576       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 16, 16, 384)  1536        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 16, 16, 384)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 16, 16, 384)  9600        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 16, 16, 384)  1536        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 16, 16, 384)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 384)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 384)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 16, 16, 384)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 16, 16, 64)   24576       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 16, 16, 64)   256         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 16, 16, 64)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 16, 16, 64)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 16, 16, 384)  24576       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 16, 16, 384)  1536        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 16, 16, 384)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 16, 16, 384)  9600        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 16, 16, 384)  1536        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 16, 16, 384)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 384)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 384)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 16, 16, 384)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 16, 16, 64)   24576       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 16, 16, 64)   256         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 16, 16, 64)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 16, 16, 64)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 16, 16, 384)  24576       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 16, 16, 384)  1536        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 16, 16, 384)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 16, 16, 384)  9600        block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 16, 16, 384)  1536        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 16, 16, 384)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 384)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 384)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 16, 16, 384)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 16, 16, 64)   24576       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 16, 16, 64)   256         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 16, 16, 64)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 16, 16, 64)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 16, 16, 384)  24576       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 16, 16, 384)  1536        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 16, 16, 384)  0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 16, 16, 384)  9600        block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 16, 16, 384)  1536        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 16, 16, 384)  0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 384)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 384)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 16, 16, 384)  0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# __________________________________________________________________________________________________
# block3e_project_conv (Conv2D)   (None, 16, 16, 64)   24576       block3e_se_excite[0][0]
# __________________________________________________________________________________________________
# block3e_project_bn (BatchNormal (None, 16, 16, 64)   256         block3e_project_conv[0][0]
# __________________________________________________________________________________________________
# block3e_drop (Dropout)          (None, 16, 16, 64)   0           block3e_project_bn[0][0]
# __________________________________________________________________________________________________
# block3e_add (Add)               (None, 16, 16, 64)   0           block3e_drop[0][0]
#                                                                  block3d_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 16, 16, 384)  24576       block3e_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 16, 16, 384)  1536        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 16, 16, 384)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 17, 17, 384)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 8, 8, 384)    3456        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 8, 8, 384)    1536        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 8, 8, 384)    0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 384)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 384)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 8, 8, 384)    0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 8, 8, 128)    49152       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 8, 8, 128)    512         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 8, 8, 768)    98304       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 8, 8, 768)    3072        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 8, 8, 768)    0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 8, 8, 768)    6912        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 8, 8, 768)    3072        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 8, 8, 768)    0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 768)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 768)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 32)     24608       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 768)    25344       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 8, 8, 768)    0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 8, 8, 128)    98304       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 8, 8, 128)    512         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 8, 8, 128)    0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 8, 8, 128)    0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 8, 8, 768)    98304       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 8, 8, 768)    3072        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 8, 8, 768)    0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 8, 8, 768)    6912        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 8, 8, 768)    3072        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 8, 8, 768)    0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 768)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 768)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 32)     24608       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 768)    25344       block4c_se_reduce[0][0]
# ...
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 4, 4, 512)    933888      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 4, 4, 512)    2048        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 4, 4, 3072)   1572864     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 4, 4, 3072)   12288       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 4, 4, 3072)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 4, 4, 3072)   27648       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 4, 4, 3072)   12288       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 4, 4, 3072)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3072)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3072)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 128)    393344      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3072)   396288      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 4, 4, 3072)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 4, 4, 512)    1572864     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 4, 4, 512)    2048        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 4, 4, 512)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 4, 4, 512)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 4, 4, 3072)   1572864     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 4, 4, 3072)   12288       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 4, 4, 3072)   0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 4, 4, 3072)   27648       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 4, 4, 3072)   12288       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 4, 4, 3072)   0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3072)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3072)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 128)    393344      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3072)   396288      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 4, 4, 3072)   0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 4, 4, 512)    1572864     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 4, 4, 512)    2048        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (Dropout)          (None, 4, 4, 512)    0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 4, 4, 512)    0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 4, 4, 2048)   1048576     block7c_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 4, 4, 2048)   8192        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 4, 4, 2048)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 512)    4194816     top_activation[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 1568)   0           conv2d_transpose[0][0]
#                                                                  block6a_expand_activation[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 8, 8, 512)    7225856     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 8, 8, 512)    2048        conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 8, 8, 512)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 512)    2359808     activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 512)    2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 8, 512)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 256)  524544      activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 640)  0           conv2d_transpose_1[0][0]
#                                                                  block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 256)  1474816     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 256)  590080      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 128)  131200      activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 368)  0           conv2d_transpose_2[0][0]
#                                                                  block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  424064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   32832       activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 208)  0           conv2d_transpose_3[0][0]
#                                                                  block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   119872      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 32) 8224        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 32) 128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 128, 128, 32) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 32) 9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 32) 128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 128, 32) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 17) 561         activation_9[0][0]
# ==================================================================================================
# Total params: 45,811,144
# Trainable params: 17,293,649
# Non-trainable params: 28,517,495
# __________________________________________________________________________________________________

# %% [markdown]
# ### Training phase
# Configure the model for the training

# %%
# Combo loss 
loss = sm.losses.BinaryFocalLoss() + sm.losses.DiceLoss(class_weights=class_weights)

threshold = 0.5
metrics = [  sm.metrics.IOUScore(threshold=threshold)
           , sm.metrics.Precision(threshold=threshold)
           , sm.metrics.Recall(threshold=threshold)
           , sm.metrics.FScore(threshold=threshold)]

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001)
              , loss=loss
              , metrics=metrics)

# %%
cp_file_name = "weights_model_D_80e.h5"

callbacks = [
    # Model checkpoint save weights ad other informations
    tf.keras.callbacks.ModelCheckpoint(  cp_file_name 
                                       , monitor = 'loss'    # Select which quantity to refers, can also use metrics or the validation 
                                       , verbose = 1
                                       , save_best_only = True 
                                       , mode = 'auto' 
                                       , save_freq = 'epoch' # Flag to save at each epoch 
                                       )
    , tf.keras.callbacks.TensorBoard(log_dir="tensorboard_model_D")
]

# Train the model, doing validation at the end of each epoch.
epochs = 80
history = model.fit(train_gen, epochs=epochs, validation_data=val_gen, callbacks=callbacks)
# Out:
# Epoch 1/80
# 169/169 [==============================] - 1330s 8s/step - loss: 1.0769 - iou_score: 0.0479 - precision: 0.2203 - recall: 0.3134 - f1-score: 0.0685 - val_loss: 1.0099 - val_iou_score: 0.0692 - val_precision: 0.5759 - val_recall: 0.0854 - val_f1-score: 0.0827
#
# Epoch 00001: loss improved from inf to 1.02986, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 2/80
# 169/169 [==============================] - 1207s 7s/step - loss: 0.9564 - iou_score: 0.1446 - precision: 0.4652 - recall: 0.2731 - f1-score: 0.1979 - val_loss: 0.9574 - val_iou_score: 0.1048 - val_precision: 0.2033 - val_recall: 0.2860 - val_f1-score: 0.1580
#
# Epoch 00002: loss improved from 1.02986 to 0.92867, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 3/80
# 169/169 [==============================] - 1162s 7s/step - loss: 0.8165 - iou_score: 0.2477 - precision: 0.3464 - recall: 0.4156 - f1-score: 0.3378 - val_loss: 0.8603 - val_iou_score: 0.1900 - val_precision: 0.3158 - val_recall: 0.4250 - val_f1-score: 0.2738
#
# Epoch 00003: loss improved from 0.92867 to 0.79039, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 4/80
# 169/169 [==============================] - 1065s 6s/step - loss: 0.7192 - iou_score: 0.3142 - precision: 0.4392 - recall: 0.4733 - f1-score: 0.4216 - val_loss: 0.7374 - val_iou_score: 0.2907 - val_precision: 0.3909 - val_recall: 0.5520 - val_f1-score: 0.4024
#
# Epoch 00004: loss improved from 0.79039 to 0.70760, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 5/80
# 169/169 [==============================] - 1062s 6s/step - loss: 0.6694 - iou_score: 0.3505 - precision: 0.4899 - recall: 0.5144 - f1-score: 0.4625 - val_loss: 0.6384 - val_iou_score: 0.3721 - val_precision: 0.5475 - val_recall: 0.5271 - val_f1-score: 0.4853
#
# Epoch 00005: loss improved from 0.70760 to 0.66110, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 6/80
# 169/169 [==============================] - 996s 6s/step - loss: 0.6157 - iou_score: 0.3974 - precision: 0.5450 - recall: 0.5556 - f1-score: 0.5147 - val_loss: 0.6104 - val_iou_score: 0.3923 - val_precision: 0.5939 - val_recall: 0.4912 - val_f1-score: 0.5081
#
# Epoch 00006: loss improved from 0.66110 to 0.61737, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 7/80
# 169/169 [==============================] - 982s 6s/step - loss: 0.6217 - iou_score: 0.3941 - precision: 0.5418 - recall: 0.5570 - f1-score: 0.5104 - val_loss: 0.6328 - val_iou_score: 0.3743 - val_precision: 0.5929 - val_recall: 0.5250 - val_f1-score: 0.4858
#
# Epoch 00007: loss improved from 0.61737 to 0.61352, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 8/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.5888 - iou_score: 0.4196 - precision: 0.5695 - recall: 0.5794 - f1-score: 0.5374 - val_loss: 0.6296 - val_iou_score: 0.3809 - val_precision: 0.5709 - val_recall: 0.5247 - val_f1-score: 0.4923
#
# Epoch 00008: loss improved from 0.61352 to 0.59222, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 9/80
# 169/169 [==============================] - 1038s 6s/step - loss: 0.5696 - iou_score: 0.4356 - precision: 0.5900 - recall: 0.5969 - f1-score: 0.5561 - val_loss: 0.5726 - val_iou_score: 0.4244 - val_precision: 0.5609 - val_recall: 0.6156 - val_f1-score: 0.5539
#
# Epoch 00009: loss improved from 0.59222 to 0.57804, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 10/80
# 169/169 [==============================] - 1052s 6s/step - loss: 0.5778 - iou_score: 0.4301 - precision: 0.5873 - recall: 0.5927 - f1-score: 0.5510 - val_loss: 0.5895 - val_iou_score: 0.4093 - val_precision: 0.6282 - val_recall: 0.5121 - val_f1-score: 0.5269
#
# Epoch 00010: loss improved from 0.57804 to 0.56747, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 11/80
# 169/169 [==============================] - 1025s 6s/step - loss: 0.5595 - iou_score: 0.4434 - precision: 0.6028 - recall: 0.6006 - f1-score: 0.5627 - val_loss: 0.5917 - val_iou_score: 0.4150 - val_precision: 0.6253 - val_recall: 0.5218 - val_f1-score: 0.5258
#
# Epoch 00011: loss improved from 0.56747 to 0.55720, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 12/80
# 169/169 [==============================] - 994s 6s/step - loss: 0.5539 - iou_score: 0.4551 - precision: 0.6162 - recall: 0.6129 - f1-score: 0.5763 - val_loss: 0.5376 - val_iou_score: 0.4666 - val_precision: 0.6553 - val_recall: 0.5815 - val_f1-score: 0.5864
#
# Epoch 00012: loss improved from 0.55720 to 0.54978, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 13/80
# 169/169 [==============================] - 1070s 6s/step - loss: 0.5432 - iou_score: 0.4618 - precision: 0.6198 - recall: 0.6196 - f1-score: 0.5831 - val_loss: 0.5842 - val_iou_score: 0.4116 - val_precision: 0.5902 - val_recall: 0.5921 - val_f1-score: 0.5342
#
# Epoch 00013: loss improved from 0.54978 to 0.54459, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 14/80
# 169/169 [==============================] - 1166s 7s/step - loss: 0.5230 - iou_score: 0.4745 - precision: 0.6341 - recall: 0.6281 - f1-score: 0.5962 - val_loss: 0.5607 - val_iou_score: 0.4294 - val_precision: 0.6351 - val_recall: 0.5415 - val_f1-score: 0.5441
#
# Epoch 00014: loss improved from 0.54459 to 0.53538, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 15/80
# 169/169 [==============================] - 1193s 7s/step - loss: 0.5193 - iou_score: 0.4790 - precision: 0.6396 - recall: 0.6307 - f1-score: 0.6010 - val_loss: 0.5226 - val_iou_score: 0.4742 - val_precision: 0.6233 - val_recall: 0.6197 - val_f1-score: 0.5943
#
# Epoch 00015: loss improved from 0.53538 to 0.52462, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 16/80
# 169/169 [==============================] - 1186s 7s/step - loss: 0.5144 - iou_score: 0.4839 - precision: 0.6389 - recall: 0.6356 - f1-score: 0.6059 - val_loss: 0.5644 - val_iou_score: 0.4243 - val_precision: 0.6273 - val_recall: 0.5328 - val_f1-score: 0.5412
#
# Epoch 00016: loss improved from 0.52462 to 0.51754, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 17/80
# 169/169 [==============================] - 1187s 7s/step - loss: 0.5120 - iou_score: 0.4855 - precision: 0.6503 - recall: 0.6305 - f1-score: 0.6056 - val_loss: 0.5632 - val_iou_score: 0.4242 - val_precision: 0.6172 - val_recall: 0.5505 - val_f1-score: 0.5404
#
# Epoch 00017: loss improved from 0.51754 to 0.50754, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 18/80
# 169/169 [==============================] - 1222s 7s/step - loss: 0.4966 - iou_score: 0.5004 - precision: 0.6629 - recall: 0.6482 - f1-score: 0.6228 - val_loss: 0.5546 - val_iou_score: 0.4562 - val_precision: 0.6781 - val_recall: 0.5657 - val_f1-score: 0.5722
#
# Epoch 00018: loss improved from 0.50754 to 0.50429, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 19/80
# 169/169 [==============================] - 1195s 7s/step - loss: 0.5048 - iou_score: 0.4958 - precision: 0.6578 - recall: 0.6483 - f1-score: 0.6178 - val_loss: 0.5426 - val_iou_score: 0.4669 - val_precision: 0.6279 - val_recall: 0.6367 - val_f1-score: 0.5884
#
# Epoch 00019: loss did not improve from 0.50429
# Epoch 20/80
# 169/169 [==============================] - 1186s 7s/step - loss: 0.4944 - iou_score: 0.5042 - precision: 0.6607 - recall: 0.6525 - f1-score: 0.6238 - val_loss: 0.5394 - val_iou_score: 0.4580 - val_precision: 0.6569 - val_recall: 0.5779 - val_f1-score: 0.5724
#
# Epoch 00020: loss improved from 0.50429 to 0.49743, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 21/80
# 169/169 [==============================] - 1185s 7s/step - loss: 0.5035 - iou_score: 0.4972 - precision: 0.6617 - recall: 0.6460 - f1-score: 0.6194 - val_loss: 0.5284 - val_iou_score: 0.4706 - val_precision: 0.6609 - val_recall: 0.5748 - val_f1-score: 0.5890
#
# Epoch 00021: loss did not improve from 0.49743
# Epoch 22/80
# 169/169 [==============================] - 1179s 7s/step - loss: 0.4876 - iou_score: 0.5083 - precision: 0.6672 - recall: 0.6606 - f1-score: 0.6292 - val_loss: 0.5566 - val_iou_score: 0.4471 - val_precision: 0.6172 - val_recall: 0.5855 - val_f1-score: 0.5635
#
# Epoch 00022: loss improved from 0.49743 to 0.49110, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 23/80
# 169/169 [==============================] - 1206s 7s/step - loss: 0.4826 - iou_score: 0.5127 - precision: 0.6775 - recall: 0.6567 - f1-score: 0.6328 - val_loss: 0.5510 - val_iou_score: 0.4499 - val_precision: 0.6699 - val_recall: 0.5424 - val_f1-score: 0.5625
#
# Epoch 00023: loss improved from 0.49110 to 0.48363, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 24/80
# 169/169 [==============================] - 1154s 7s/step - loss: 0.4756 - iou_score: 0.5231 - precision: 0.6853 - recall: 0.6644 - f1-score: 0.6443 - val_loss: 0.5279 - val_iou_score: 0.4815 - val_precision: 0.6777 - val_recall: 0.5737 - val_f1-score: 0.5949
#
# Epoch 00024: loss improved from 0.48363 to 0.47897, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 25/80
# 169/169 [==============================] - 1163s 7s/step - loss: 0.4710 - iou_score: 0.5332 - precision: 0.6960 - recall: 0.6738 - f1-score: 0.6522 - val_loss: 0.5513 - val_iou_score: 0.4629 - val_precision: 0.6679 - val_recall: 0.5831 - val_f1-score: 0.5773
#
# Epoch 00025: loss improved from 0.47897 to 0.47703, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 26/80
# 169/169 [==============================] - 980s 6s/step - loss: 0.4740 - iou_score: 0.5218 - precision: 0.6888 - recall: 0.6682 - f1-score: 0.6421 - val_loss: 0.5376 - val_iou_score: 0.4639 - val_precision: 0.6505 - val_recall: 0.5830 - val_f1-score: 0.5781
#
# Epoch 00026: loss improved from 0.47703 to 0.47485, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 27/80
# 169/169 [==============================] - 1057s 6s/step - loss: 0.4644 - iou_score: 0.5267 - precision: 0.6938 - recall: 0.6728 - f1-score: 0.6502 - val_loss: 0.5039 - val_iou_score: 0.4943 - val_precision: 0.6788 - val_recall: 0.6027 - val_f1-score: 0.6119
#
# Epoch 00027: loss improved from 0.47485 to 0.46308, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 28/80
# 169/169 [==============================] - 1131s 7s/step - loss: 0.4680 - iou_score: 0.5310 - precision: 0.6932 - recall: 0.6704 - f1-score: 0.6518 - val_loss: 0.5311 - val_iou_score: 0.4630 - val_precision: 0.6710 - val_recall: 0.5616 - val_f1-score: 0.5775
#
# Epoch 00028: loss did not improve from 0.46308
# Epoch 29/80
# 169/169 [==============================] - 1153s 7s/step - loss: 0.4542 - iou_score: 0.5436 - precision: 0.7057 - recall: 0.6804 - f1-score: 0.6625 - val_loss: 0.5438 - val_iou_score: 0.4571 - val_precision: 0.6820 - val_recall: 0.5400 - val_f1-score: 0.5706
#
# Epoch 00029: loss improved from 0.46308 to 0.46043, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 30/80
# 169/169 [==============================] - 1015s 6s/step - loss: 0.4588 - iou_score: 0.5408 - precision: 0.7023 - recall: 0.6821 - f1-score: 0.6607 - val_loss: 0.5371 - val_iou_score: 0.4759 - val_precision: 0.6940 - val_recall: 0.5909 - val_f1-score: 0.5918
#
# Epoch 00030: loss improved from 0.46043 to 0.45767, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 31/80
# 169/169 [==============================] - 987s 6s/step - loss: 0.4708 - iou_score: 0.5281 - precision: 0.6873 - recall: 0.6816 - f1-score: 0.6486 - val_loss: 0.5613 - val_iou_score: 0.4666 - val_precision: 0.6437 - val_recall: 0.6229 - val_f1-score: 0.5857
#
# Epoch 00031: loss did not improve from 0.45767
# Epoch 32/80
# 169/169 [==============================] - 982s 6s/step - loss: 0.4509 - iou_score: 0.5473 - precision: 0.7064 - recall: 0.6845 - f1-score: 0.6674 - val_loss: 0.5285 - val_iou_score: 0.4713 - val_precision: 0.6633 - val_recall: 0.5954 - val_f1-score: 0.5871
#
# Epoch 00032: loss improved from 0.45767 to 0.45351, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 33/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.4536 - iou_score: 0.5432 - precision: 0.7047 - recall: 0.6860 - f1-score: 0.6642 - val_loss: 0.5124 - val_iou_score: 0.4809 - val_precision: 0.6442 - val_recall: 0.6125 - val_f1-score: 0.6032
#
# Epoch 00033: loss did not improve from 0.45351
# Epoch 34/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.4461 - iou_score: 0.5473 - precision: 0.7079 - recall: 0.6853 - f1-score: 0.6663 - val_loss: 0.5847 - val_iou_score: 0.4100 - val_precision: 0.6730 - val_recall: 0.4991 - val_f1-score: 0.5147
#
# Epoch 00034: loss improved from 0.45351 to 0.44903, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 35/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.4368 - iou_score: 0.5577 - precision: 0.7170 - recall: 0.6948 - f1-score: 0.6773 - val_loss: 0.5251 - val_iou_score: 0.4739 - val_precision: 0.6925 - val_recall: 0.5597 - val_f1-score: 0.5881
#
# Epoch 00035: loss improved from 0.44903 to 0.44335, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 36/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.4513 - iou_score: 0.5465 - precision: 0.7147 - recall: 0.6867 - f1-score: 0.6661 - val_loss: 0.5281 - val_iou_score: 0.4799 - val_precision: 0.7309 - val_recall: 0.5749 - val_f1-score: 0.5957
#
# Epoch 00036: loss improved from 0.44335 to 0.44301, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 37/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.4457 - iou_score: 0.5548 - precision: 0.7131 - recall: 0.6947 - f1-score: 0.6734 - val_loss: 0.5466 - val_iou_score: 0.4714 - val_precision: 0.6892 - val_recall: 0.5831 - val_f1-score: 0.5836
#
# Epoch 00037: loss did not improve from 0.44301
# Epoch 38/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.4365 - iou_score: 0.5583 - precision: 0.7208 - recall: 0.6909 - f1-score: 0.6786 - val_loss: 0.5371 - val_iou_score: 0.4683 - val_precision: 0.6856 - val_recall: 0.5821 - val_f1-score: 0.5817
#
# Epoch 00038: loss improved from 0.44301 to 0.43858, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 39/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.4244 - iou_score: 0.5695 - precision: 0.7316 - recall: 0.7071 - f1-score: 0.6894 - val_loss: 0.5124 - val_iou_score: 0.4828 - val_precision: 0.6675 - val_recall: 0.5999 - val_f1-score: 0.6027
#
# Epoch 00039: loss improved from 0.43858 to 0.43122, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 40/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.4239 - iou_score: 0.5679 - precision: 0.7312 - recall: 0.7036 - f1-score: 0.6882 - val_loss: 0.5837 - val_iou_score: 0.4183 - val_precision: 0.6733 - val_recall: 0.5258 - val_f1-score: 0.5317
#
# Epoch 00040: loss did not improve from 0.43122
# Epoch 41/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.4316 - iou_score: 0.5655 - precision: 0.7249 - recall: 0.7034 - f1-score: 0.6834 - val_loss: 0.5420 - val_iou_score: 0.4659 - val_precision: 0.6614 - val_recall: 0.5493 - val_f1-score: 0.5741
#
# Epoch 00041: loss improved from 0.43122 to 0.42639, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 42/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.4284 - iou_score: 0.5666 - precision: 0.7257 - recall: 0.7078 - f1-score: 0.6853 - val_loss: 0.5510 - val_iou_score: 0.4729 - val_precision: 0.6665 - val_recall: 0.5931 - val_f1-score: 0.5840
#
# Epoch 00042: loss improved from 0.42639 to 0.42538, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 43/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.4222 - iou_score: 0.5790 - precision: 0.7417 - recall: 0.7124 - f1-score: 0.6977 - val_loss: 0.5464 - val_iou_score: 0.4653 - val_precision: 0.6681 - val_recall: 0.6031 - val_f1-score: 0.5808
#
# Epoch 00043: loss did not improve from 0.42538
# Epoch 44/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.4153 - iou_score: 0.5848 - precision: 0.7452 - recall: 0.7152 - f1-score: 0.7022 - val_loss: 0.5490 - val_iou_score: 0.4683 - val_precision: 0.7201 - val_recall: 0.5780 - val_f1-score: 0.5775
#
# Epoch 00044: loss improved from 0.42538 to 0.41990, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 45/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.4208 - iou_score: 0.5739 - precision: 0.7380 - recall: 0.7104 - f1-score: 0.6936 - val_loss: 0.5131 - val_iou_score: 0.4958 - val_precision: 0.7266 - val_recall: 0.5849 - val_f1-score: 0.6087
#
# Epoch 00045: loss did not improve from 0.41990
# Epoch 46/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.4254 - iou_score: 0.5703 - precision: 0.7328 - recall: 0.7044 - f1-score: 0.6887 - val_loss: 0.5401 - val_iou_score: 0.4695 - val_precision: 0.6841 - val_recall: 0.5873 - val_f1-score: 0.5798
#
# Epoch 00046: loss did not improve from 0.41990
# Epoch 47/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.4156 - iou_score: 0.5795 - precision: 0.7404 - recall: 0.7133 - f1-score: 0.6969 - val_loss: 0.5282 - val_iou_score: 0.4877 - val_precision: 0.6817 - val_recall: 0.5853 - val_f1-score: 0.5951
#
# Epoch 00047: loss improved from 0.41990 to 0.41322, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 48/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.4118 - iou_score: 0.5885 - precision: 0.7433 - recall: 0.7233 - f1-score: 0.7046 - val_loss: 0.5440 - val_iou_score: 0.4783 - val_precision: 0.7315 - val_recall: 0.5707 - val_f1-score: 0.5877
#
# Epoch 00048: loss improved from 0.41322 to 0.41208, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 49/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.4145 - iou_score: 0.5867 - precision: 0.7461 - recall: 0.7220 - f1-score: 0.7037 - val_loss: 0.5430 - val_iou_score: 0.4858 - val_precision: 0.6739 - val_recall: 0.6192 - val_f1-score: 0.6042
#
# Epoch 00049: loss did not improve from 0.41208
# Epoch 50/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.4144 - iou_score: 0.5810 - precision: 0.7510 - recall: 0.7074 - f1-score: 0.7006 - val_loss: 0.5282 - val_iou_score: 0.4755 - val_precision: 0.7167 - val_recall: 0.5659 - val_f1-score: 0.5865
#
# Epoch 00050: loss did not improve from 0.41208
# Epoch 51/80
# 169/169 [==============================] - 981s 6s/step - loss: 0.4074 - iou_score: 0.5873 - precision: 0.7453 - recall: 0.7200 - f1-score: 0.7051 - val_loss: 0.5135 - val_iou_score: 0.4909 - val_precision: 0.7107 - val_recall: 0.5781 - val_f1-score: 0.6040
#
# Epoch 00051: loss did not improve from 0.41208
# Epoch 52/80
# 169/169 [==============================] - 982s 6s/step - loss: 0.4183 - iou_score: 0.5767 - precision: 0.7402 - recall: 0.7106 - f1-score: 0.6948 - val_loss: 0.5253 - val_iou_score: 0.4800 - val_precision: 0.6859 - val_recall: 0.5999 - val_f1-score: 0.5946
#
# Epoch 00052: loss did not improve from 0.41208
# Epoch 53/80
# 169/169 [==============================] - 980s 6s/step - loss: 0.4023 - iou_score: 0.5944 - precision: 0.7531 - recall: 0.7250 - f1-score: 0.7109 - val_loss: 0.5238 - val_iou_score: 0.4832 - val_precision: 0.6407 - val_recall: 0.5950 - val_f1-score: 0.5920
#
# Epoch 00053: loss improved from 0.41208 to 0.40563, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 54/80
# 169/169 [==============================] - 983s 6s/step - loss: 0.4059 - iou_score: 0.5941 - precision: 0.7576 - recall: 0.7245 - f1-score: 0.7107 - val_loss: 0.5277 - val_iou_score: 0.4869 - val_precision: 0.7365 - val_recall: 0.5614 - val_f1-score: 0.5973
#
# Epoch 00054: loss improved from 0.40563 to 0.40180, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 55/80
# 169/169 [==============================] - 983s 6s/step - loss: 0.3961 - iou_score: 0.6029 - precision: 0.7620 - recall: 0.7319 - f1-score: 0.7198 - val_loss: 0.5462 - val_iou_score: 0.4835 - val_precision: 0.6835 - val_recall: 0.5992 - val_f1-score: 0.5939
#
# Epoch 00055: loss did not improve from 0.40180
# Epoch 56/80
# 169/169 [==============================] - 994s 6s/step - loss: 0.3998 - iou_score: 0.5942 - precision: 0.7485 - recall: 0.7233 - f1-score: 0.7114 - val_loss: 0.5493 - val_iou_score: 0.4735 - val_precision: 0.7145 - val_recall: 0.5735 - val_f1-score: 0.5800
#
# Epoch 00056: loss improved from 0.40180 to 0.40034, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 57/80
# 169/169 [==============================] - 982s 6s/step - loss: 0.3907 - iou_score: 0.6051 - precision: 0.7640 - recall: 0.7340 - f1-score: 0.7226 - val_loss: 0.5107 - val_iou_score: 0.4936 - val_precision: 0.7279 - val_recall: 0.6023 - val_f1-score: 0.6087
#
# Epoch 00057: loss improved from 0.40034 to 0.39319, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 58/80
# 169/169 [==============================] - 983s 6s/step - loss: 0.3992 - iou_score: 0.5996 - precision: 0.7601 - recall: 0.7275 - f1-score: 0.7162 - val_loss: 0.5196 - val_iou_score: 0.4817 - val_precision: 0.6479 - val_recall: 0.6046 - val_f1-score: 0.5966
#
# Epoch 00058: loss did not improve from 0.39319
# Epoch 59/80
# 169/169 [==============================] - 986s 6s/step - loss: 0.3850 - iou_score: 0.6105 - precision: 0.7652 - recall: 0.7378 - f1-score: 0.7249 - val_loss: 0.5242 - val_iou_score: 0.4840 - val_precision: 0.7198 - val_recall: 0.5664 - val_f1-score: 0.5952
#
# Epoch 00059: loss improved from 0.39319 to 0.39094, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 60/80
# 169/169 [==============================] - 984s 6s/step - loss: 0.3813 - iou_score: 0.6147 - precision: 0.7725 - recall: 0.7376 - f1-score: 0.7304 - val_loss: 0.5398 - val_iou_score: 0.4863 - val_precision: 0.6898 - val_recall: 0.5897 - val_f1-score: 0.5916
#
# Epoch 00060: loss did not improve from 0.39094
# Epoch 61/80
# 169/169 [==============================] - 981s 6s/step - loss: 0.4054 - iou_score: 0.5980 - precision: 0.7520 - recall: 0.7337 - f1-score: 0.7129 - val_loss: 0.5351 - val_iou_score: 0.4840 - val_precision: 0.6990 - val_recall: 0.5913 - val_f1-score: 0.5977
#
# Epoch 00061: loss did not improve from 0.39094
# Epoch 62/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.3940 - iou_score: 0.6047 - precision: 0.7619 - recall: 0.7328 - f1-score: 0.7193 - val_loss: 0.5397 - val_iou_score: 0.4733 - val_precision: 0.7087 - val_recall: 0.5668 - val_f1-score: 0.5784
#
# Epoch 00062: loss improved from 0.39094 to 0.38975, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 63/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.3875 - iou_score: 0.6163 - precision: 0.7750 - recall: 0.7394 - f1-score: 0.7322 - val_loss: 0.5286 - val_iou_score: 0.4772 - val_precision: 0.7239 - val_recall: 0.5730 - val_f1-score: 0.5896
#
# Epoch 00063: loss improved from 0.38975 to 0.38187, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 64/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.3852 - iou_score: 0.6159 - precision: 0.7702 - recall: 0.7387 - f1-score: 0.7310 - val_loss: 0.5106 - val_iou_score: 0.4930 - val_precision: 0.6815 - val_recall: 0.5946 - val_f1-score: 0.6043
#
# Epoch 00064: loss did not improve from 0.38187
# Epoch 65/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.3819 - iou_score: 0.6136 - precision: 0.7681 - recall: 0.7418 - f1-score: 0.7285 - val_loss: 0.5312 - val_iou_score: 0.4762 - val_precision: 0.7230 - val_recall: 0.5524 - val_f1-score: 0.5850
#
# Epoch 00065: loss did not improve from 0.38187
# Epoch 66/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.3830 - iou_score: 0.6168 - precision: 0.7741 - recall: 0.7400 - f1-score: 0.7310 - val_loss: 0.5064 - val_iou_score: 0.5014 - val_precision: 0.7332 - val_recall: 0.5957 - val_f1-score: 0.6154
#
# Epoch 00066: loss did not improve from 0.38187
# Epoch 67/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.3862 - iou_score: 0.6184 - precision: 0.7720 - recall: 0.7488 - f1-score: 0.7341 - val_loss: 0.5302 - val_iou_score: 0.4851 - val_precision: 0.6878 - val_recall: 0.6126 - val_f1-score: 0.5999
#
# Epoch 00067: loss did not improve from 0.38187
# Epoch 68/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.3773 - iou_score: 0.6204 - precision: 0.7765 - recall: 0.7468 - f1-score: 0.7358 - val_loss: 0.5233 - val_iou_score: 0.4809 - val_precision: 0.7003 - val_recall: 0.5847 - val_f1-score: 0.5944
#
# Epoch 00068: loss did not improve from 0.38187
# Epoch 69/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.3708 - iou_score: 0.6284 - precision: 0.7771 - recall: 0.7554 - f1-score: 0.7427 - val_loss: 0.5175 - val_iou_score: 0.4963 - val_precision: 0.6984 - val_recall: 0.6078 - val_f1-score: 0.6051
#
# Epoch 00069: loss improved from 0.38187 to 0.37395, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 70/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.3717 - iou_score: 0.6290 - precision: 0.7855 - recall: 0.7442 - f1-score: 0.7424 - val_loss: 0.5299 - val_iou_score: 0.4782 - val_precision: 0.6727 - val_recall: 0.5937 - val_f1-score: 0.5889
#
# Epoch 00070: loss did not improve from 0.37395
# Epoch 71/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.3704 - iou_score: 0.6310 - precision: 0.7894 - recall: 0.7472 - f1-score: 0.7432 - val_loss: 0.5246 - val_iou_score: 0.4814 - val_precision: 0.7248 - val_recall: 0.5615 - val_f1-score: 0.5918
#
# Epoch 00071: loss did not improve from 0.37395
# Epoch 72/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.3737 - iou_score: 0.6312 - precision: 0.7857 - recall: 0.7511 - f1-score: 0.7422 - val_loss: 0.5328 - val_iou_score: 0.4887 - val_precision: 0.7645 - val_recall: 0.5705 - val_f1-score: 0.5968
#
# Epoch 00072: loss improved from 0.37395 to 0.37291, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 73/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.3793 - iou_score: 0.6233 - precision: 0.7769 - recall: 0.7484 - f1-score: 0.7365 - val_loss: 0.5469 - val_iou_score: 0.4757 - val_precision: 0.6974 - val_recall: 0.5896 - val_f1-score: 0.5913
#
# Epoch 00073: loss did not improve from 0.37291
# Epoch 74/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.3751 - iou_score: 0.6347 - precision: 0.7924 - recall: 0.7499 - f1-score: 0.7479 - val_loss: 0.5262 - val_iou_score: 0.4807 - val_precision: 0.7020 - val_recall: 0.5913 - val_f1-score: 0.5915
#
# Epoch 00074: loss did not improve from 0.37291
# Epoch 75/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.3703 - iou_score: 0.6265 - precision: 0.7858 - recall: 0.7469 - f1-score: 0.7421 - val_loss: 0.5103 - val_iou_score: 0.4859 - val_precision: 0.7399 - val_recall: 0.5743 - val_f1-score: 0.6044
#
# Epoch 00075: loss did not improve from 0.37291
# Epoch 76/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.3737 - iou_score: 0.6230 - precision: 0.7831 - recall: 0.7464 - f1-score: 0.7378 - val_loss: 0.5168 - val_iou_score: 0.4837 - val_precision: 0.7084 - val_recall: 0.5806 - val_f1-score: 0.5940
#
# Epoch 00076: loss did not improve from 0.37291
# Epoch 77/80
# 169/169 [==============================] - 959s 6s/step - loss: 0.3665 - iou_score: 0.6301 - precision: 0.7844 - recall: 0.7534 - f1-score: 0.7420 - val_loss: 0.5143 - val_iou_score: 0.4897 - val_precision: 0.6970 - val_recall: 0.5799 - val_f1-score: 0.6012
#
# Epoch 00077: loss did not improve from 0.37291
# Epoch 78/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.3737 - iou_score: 0.6311 - precision: 0.7898 - recall: 0.7482 - f1-score: 0.7445 - val_loss: 0.5288 - val_iou_score: 0.4932 - val_precision: 0.7237 - val_recall: 0.5943 - val_f1-score: 0.6021
#
# Epoch 00078: loss improved from 0.37291 to 0.36922, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5
# Epoch 79/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.3674 - iou_score: 0.6335 - precision: 0.7911 - recall: 0.7557 - f1-score: 0.7461 - val_loss: 0.5496 - val_iou_score: 0.4829 - val_precision: 0.6849 - val_recall: 0.6078 - val_f1-score: 0.5910
#
# Epoch 00079: loss did not improve from 0.36922
# Epoch 80/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.3583 - iou_score: 0.6417 - precision: 0.7959 - recall: 0.7574 - f1-score: 0.7535 - val_loss: 0.5189 - val_iou_score: 0.4944 - val_precision: 0.7107 - val_recall: 0.6102 - val_f1-score: 0.6035
#
# Epoch 00080: loss improved from 0.36922 to 0.36314, saving model to model\food_segmentation_80_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_effunet_20210612-111116.h5

# %% [markdown]
# ### History of the training
# Plot metrics evolution from 0 to 80 epoch during the training

# %%
import matplotlib.pyplot as plt
def plot_history(model_history, keys, labels=("epochs", "metrics"), figsize=(10,5)):
    
    fig = plt.figure(figsize=figsize)
    
    # take all pairs of training and val metrics
    for i in range(0, len(keys), 2):
        m, val_m = keys[i], keys[i+1]
        
        plt.plot(model_history.history[m])
        plt.plot(model_history.history[val_m])
        
    plt.xlabel(labels[0])
    plt.ylabel(labels[1])

    # Adding legend
    plt.legend(keys,
          title ="Legend",
          loc ="upper left",
          bbox_to_anchor =(1.0, 0, 0.5, 1))
    plt.title("Training history")
    plt.grid(True)
    plt.show()

# %%
# plot history
plot_history(history,['loss','val_loss'], labels=("epochs", "loss"), figsize=(15,7))
plot_history(history,['iou_score','val_iou_score', 'precision', 'val_precision', 'recall', 'val_recall'], figsize=(15,7))

# %% [markdown]
# Store model and history on files

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_D.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pandas as pd

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open("train_history_model_D.csv", mode="w") as file:
    hist_df.to_csv(file)
