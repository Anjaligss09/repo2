# %% [markdown]
# # **Project #4 - Food Recognition**
# ### Deep Learning course - A.Y. 2020-2021
# Students:
#
# - Giuseppe	Murro	(0000997317 $-$ giuseppe.murro@studio.unibo.it)
# - Salvatore	Pisciotta	(0000985203 $-$ salvatore.pisciotta2@studio.unibo.it)

# %% [markdown]
# ## ***TRAINING MODEL C***

# %% [markdown]
# ### Preliminary settings
# Check if the runtime is on Colab

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %% [markdown]
# Install extern libraries if they are not installed

# %%
# !pip install segmentation_models
# !pip install visualkeras

# %% [markdown]
# Clone the repo in order to access to the dataset if the runtime is on Colab

# %%
if IN_COLAB:
    # !git clone https://github.com/gmurro/FoodRecognition.git
    # %cd /content/FoodRecognition/src
    SRC_PATH = ""
else:
    # Add path of the SRC folder in order to import custom libraries
    import sys
    SRC_PATH = "../../"
    sys.path.insert(1, SRC_PATH)

# %% [markdown]
# Import useful libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import os
from PIL import Image

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

from utils import segmentation_utils

# %env SM_FRAMEWORK = tf.keras
import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# ### Data acquisition
# Define the categories of food on which we want train the segmentation model

# %%
cat_names = ['water'
             , 'bread-white'
             , 'salad-leaf-salad-green'
             , 'tomato'
             , 'butter'
             , 'carrot'
             , 'coffee-with-caffeine'
             , 'rice'
             , 'egg'
             , 'mixed-vegetables'
             , 'wine-red'
             , 'apple'
             , 'jam'
             , 'potatoes-steamed'
             , 'banana'
             , 'cheese' ]
             
batch_size = 64
img_size = (128,128)
num_classes = len(cat_names) + 1
num_filters = 32

# %% [markdown]
# Define the class `DataGenerator`, which will be used for real-time data feeding to our Keras model.
# We make the latter inherit the properties of `keras.utils.Sequence` so that we can leverage nice functionalities such as *multiprocessing*.

# %%
class DataGenerator(tf.keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, coco, batch_size, img_size, img_ids, img_paths, cat_to_class, aug_args=None, shuffle=True):
        self.coco = coco
        self.batch_size = batch_size
        self.img_size = img_size
        self.img_paths = img_paths
        self.img_ids = img_ids
        self.cat_to_class = cat_to_class
        self.aug_args = aug_args
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        """ Number of batches per epoch """
        return len(self.img_ids) // self.batch_size

    def __getitem__(self, idx):
        """ Generate one batch of data """

        # Generate indexes of the batch
        indexes = self.indexes[idx * self.batch_size:(idx + 1) * self.batch_size]

        # n of categories
        n_cat = len(self.cat_to_class)

        # Find list of img paths and image ids to read in the batch
        batch_img_paths = [self.img_paths[i] for i in indexes]
        batch_img_ids = [self.img_ids[i] for i in indexes]

        # load imgs
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype=np.float32)
        for j, path in enumerate(batch_img_paths):
            img = img_to_array(load_img(path, target_size=self.img_size))
            x[j] = img

        # load masks
        y = np.zeros((self.batch_size,) + self.img_size + (n_cat,), dtype=np.float32)
        for j, img_id in enumerate(batch_img_ids):
            mask = segmentation_utils.load_mask(self.coco, img_id, self.cat_to_class)

            # scale down mask
            mask_scaled = np.zeros(self.img_size+ (n_cat,), dtype=np.uint8)
            for i in range(n_cat):
                mask_scaled[:,:,i] = Image.fromarray(mask[:,:,i]).resize(self.img_size, Image.NEAREST)

            y[j] = np.array(mask_scaled, dtype=np.float32)
            
        if self.aug_args is not None:
            x, y = segmentation_utils.augment(x, y, self.aug_args)
            
            #
            
        return x, y

    def on_epoch_end(self):
        """ Method called at the end of every epoch that updates indexes """
        self.indexes = np.arange(len(self.img_ids))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

# %% [markdown]
# Show some examples of images from the validation set

# %%
# @title Show some images
path_dir = SRC_PATH+"../data/val/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

# load all data
x, y = segmentation_utils.load_data(coco, path_dir+"images/", img_size, cat_names)
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# Loading images:
# 552/554 [============================>.] - ETA: 0s
# Loading masks:
# 552/554 [============================>.] - ETA: 0s

# %%
# show 3 random image and compare with augmentation
n = 3

# parameters for the augmetation
aug_args = dict(
                  rotation_range=5              # @param {type:"slider", min:0, max:10, step:1}
                , width_shift_range=0.01        # @param {type:"slider", min:0, max:0.1, step:0.01}
                , height_shift_range=0.01       # @param {type:"slider", min:0, max:0.1, step:0.01}
                , brightness_range=(0.8, 1.2)  
                , shear_range=0.01              # @param {type:"slider", min:0, max:0.1, step:0.01}
                , zoom_range=[0.7, 1]           
                , horizontal_flip=True          # @param {type:"boolean"} 
                , vertical_flip=True            # @param {type:"boolean"} 
                , fill_mode='constant'          #@param ["constant", "nearest", "reflect", "wrap"] {type:"raw"}
                , data_format='channels_last')

idx = random.randint(0, len(x)-1-n)

for i in range(idx,idx+n):
    print("\nImage {}".format(i))

    # show image not augmented
    segmentation_utils.show_mask(x[i,:,:]/255, y[i,:,:,:], cat_names)

    # show the same image augmented
    x_p = x[i].reshape((1,)+x[i].shape)
    y_p = y[i].reshape((1,)+y[i].shape)
    x_aug, y_aug = segmentation_utils.augment(x_p, y_p, aug_args)
    segmentation_utils.show_mask(x_aug[0,:,:]/255, y_aug[0,:,:,:], cat_names)
# Out:
# Image 95
# Image 96
# Image 97

# %% [markdown]
# Instantiate Data Generators for training set

# %%
# @title DataGenerator from training set
path_dir = SRC_PATH+"../data/train/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

# compute the class weights
class_dist = segmentation_utils.get_class_dist(coco, cat_names)
class_weights = segmentation_utils.get_class_weights(class_dist)

img_paths = [os.path.join(path_dir+"images/", file_name) for file_name in img_names]

# parameters for the augmetation
aug_args = dict(
                  rotation_range=5              # @param {type:"slider", min:0, max:10, step:1}
                , width_shift_range=0.01        # @param {type:"slider", min:0, max:0.1, step:0.01}
                , height_shift_range=0.01       # @param {type:"slider", min:0, max:0.1, step:0.01}
                , brightness_range=(0.8, 1.2)  
                , shear_range=0.01              # @param {type:"slider", min:0, max:0.1, step:0.01}
                , zoom_range=[0.7, 1]           
                , horizontal_flip=True          # @param {type:"boolean"} 
                , vertical_flip=True            # @param {type:"boolean"} 
                , fill_mode='constant'          #@param ["constant", "nearest", "reflect", "wrap"] {type:"raw"}
                , data_format='channels_last')

# create the generator
train_gen = DataGenerator(coco, batch_size, img_size, img_ids, img_paths,  cat_to_class, aug_args)
# Out:
# loading annotations into memory...
# Done (t=1.83s)
# creating index...
# index created!

# %% [markdown]
# Show class distribution and class weights from the training set. Class weights are computed according to the following formula:
#
# $w(y) = \frac{n\_samples}{n\_classes \cdot counts(y)}$

# %%
# print class weights
print("CLASS WEIGHTS:")
for i, weight in enumerate(class_weights):
    print("\t- {}: {:.2f}".format(cat_names[i],weight))
    
# plot a pie chart of the class distribution
segmentation_utils.plot_class_dist(class_dist, cat_names, cat_to_class, without_background=True)
# Out:
# CLASS WEIGHTS:
# 	- background: 0.06
# 	- water: 0.35
# 	- egg: 1.02
# 	- butter: 0.63
# 	- bread-white: 0.50
# 	- jam: 1.27
# 	- apple: 1.26
# 	- cheese: 1.58
# 	- carrot: 0.71
# 	- salad-leaf-salad-green: 0.54
# 	- banana: 1.54
# 	- mixed-vegetables: 1.02
# 	- tomato: 0.60
# 	- wine-red: 1.17
# 	- rice: 0.97
# 	- coffee-with-caffeine: 0.73
# 	- potatoes-steamed: 1.41

# %% [markdown]
# Instantiate Data Generators for validation set

# %%
# @title DataGenerator from validation set
path_dir = SRC_PATH+"../data/val/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

img_paths = [os.path.join(path_dir+"images/", file_name) for file_name in img_names]

# create the generator
val_gen = DataGenerator(coco, batch_size, img_size, img_ids, img_paths, cat_to_class)
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!

# %% [markdown]
# ### Model architecture
# Basic U-Net

# %%
from tensorflow.keras import layers

def conv_block(input, num_filters, size=3, padding='same', initializer="he_normal"):
    x = layers.Conv2D(filters=num_filters, kernel_size=(size, size), padding=padding, kernel_initializer=initializer)(input)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2D(filters=num_filters, kernel_size=(size, size), padding=padding, kernel_initializer=initializer)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    return x


def deconv_block(input, num_filters, skip_features, size=2, padding='same', strides=(2, 2)):
    x = layers.Conv2DTranspose(num_filters, kernel_size=(size, size), strides=strides, padding=padding)(input)
    x = layers.concatenate([x, skip_features], axis=3)
    x = conv_block(x, num_filters)
    return x

def unet(img_size, num_classes, num_filters=64):
    
    ''' Input layer '''
    input_layer = layers.Input(shape=img_size + (3,), name='image_input')
    
    ''' Contractive path '''
    ### Layer 1
    conv1 = conv_block(input_layer, num_filters=num_filters)
    conv1_out = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    ### Layer 2
    conv2 = conv_block(conv1_out, num_filters=num_filters*2)
    conv2_out = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    ### Layer 3
    conv3 = conv_block(conv2_out, num_filters=num_filters*4)
    conv3_out = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    ### Layer 4
    conv4 = conv_block(conv3_out, num_filters=num_filters*8)
    conv4_out = layers.MaxPooling2D(pool_size=(2, 2))(conv4)
    conv4_out = layers.Dropout(0.5)(conv4_out)
    
    ### Layer 5
    conv5 = conv_block(conv4_out, num_filters=num_filters*16)
    conv5 = layers.Dropout(0.5)(conv5)
    
    ''' Expansive path '''
    ### Layer 6
    deconv6 = deconv_block(conv5, num_filters=num_filters*8, skip_features=conv4)
    deconv6 = layers.Dropout(0.5)(deconv6)
    
    ### Layer 7
    deconv7 = deconv_block(deconv6, num_filters=num_filters*4, skip_features=conv3,)
    
    ### Layer 8
    deconv8 = deconv_block(deconv7, num_filters=num_filters*2, skip_features=conv2)
    
    ### Layer 9
    deconv9 = deconv_block(deconv8, num_filters=num_filters, skip_features=conv1)
    
    # output: add a per-pixel classification layer
    output_layer = layers.Conv2D(filters=num_classes, kernel_size=(1, 1), activation="softmax", padding="same")(deconv9)
    
    # Define the model
    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='u-net')
    return model

# Free up RAM in case the model definition cells were run multiple times
tf.keras.backend.clear_session()

# Build model
model = unet(img_size, num_classes, num_filters=num_filters)
model.summary()
# Out:
# Model: "u-net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image_input (InputLayer)        [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 896         image_input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8, 8, 256)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 512)    0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  524544      dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 256)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  131200      dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   32832       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 32) 8224        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 17) 561         activation_17[0][0]
# ==================================================================================================
# Total params: 7,772,401
# Trainable params: 7,766,513
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# Draw model architecture

# %%
import visualkeras
from PIL import ImageFont
from collections import defaultdict

color_map = defaultdict(dict)
color_map[layers.Conv2D]['fill'] = 'red'
color_map[layers.InputLayer]['fill'] = 'gray'
color_map[layers.Dropout]['fill'] = 'blue'
color_map[layers.MaxPooling2D]['fill'] = 'yellow'
color_map[layers.Concatenate]['fill'] = 'green'
color_map[layers.Activation]['fill'] = 'purple'
color_map[layers.Conv2DTranspose]['fill'] = 'orange'


font = ImageFont.truetype("arial.ttf", 32)  
visualkeras.layered_view(model, legend=True, font=font, color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=2656x755 at 0x220B7E5EAF0>

# %% [markdown]
# ### Training phase
# Configure the model for the training

# %%
# Combo loss 
loss = sm.losses.CategoricalFocalLoss() + sm.losses.DiceLoss(class_weights=class_weights)

threshold = 0.5
metrics = [  sm.metrics.IOUScore(threshold=threshold)
           , sm.metrics.Precision(threshold=threshold)
           , sm.metrics.Recall(threshold=threshold)
           , sm.metrics.FScore(threshold=threshold)]

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001)
              , loss=loss
              , metrics=metrics)

# %%
cp_file_name = "weights_model_C_80e.h5"

callbacks = [
    # Model checkpoint save weights ad other informations
    tf.keras.callbacks.ModelCheckpoint(  cp_file_name 
                                       , monitor = 'loss'    # Select which quantity to refers, can also use metrics or the validation 
                                       , verbose = 1
                                       , save_best_only = True 
                                       , mode = 'auto' 
                                       , save_freq = 'epoch' # Flag to save at each epoch 
                                       )
    , tf.keras.callbacks.TensorBoard(log_dir="tensorboard_model_C")
]

# Train the model, doing validation at the end of each epoch.
epochs = 80
history = model.fit(train_gen, epochs=epochs, validation_data=val_gen, callbacks=callbacks)
# Out:
# Epoch 1/80
# 169/169 [==============================] - 980s 6s/step - loss: 0.9755 - mean_io_u: 0.4703 - iou_score: 0.0607 - precision: 0.5449 - recall: 0.1135 - f1-score: 0.0911 - val_loss: 1.1823 - val_mean_io_u: 0.4707 - val_iou_score: 0.0153 - val_precision: 0.3543 - val_recall: 0.1003 - val_f1-score: 0.0224
#
# Epoch 00001: loss improved from inf to 0.94770, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 2/80
# 169/169 [==============================] - 958s 6s/step - loss: 0.8877 - mean_io_u: 0.4703 - iou_score: 0.1447 - precision: 0.4309 - recall: 0.2501 - f1-score: 0.2171 - val_loss: 1.0285 - val_mean_io_u: 0.4739 - val_iou_score: 0.0684 - val_precision: 0.2117 - val_recall: 0.2099 - val_f1-score: 0.1083
#
# Epoch 00002: loss improved from 0.94770 to 0.87970, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 3/80
# 169/169 [==============================] - 966s 6s/step - loss: 0.8595 - mean_io_u: 0.4704 - iou_score: 0.1609 - precision: 0.2961 - recall: 0.2890 - f1-score: 0.2420 - val_loss: 0.9182 - val_mean_io_u: 0.4703 - val_iou_score: 0.1152 - val_precision: 0.2191 - val_recall: 0.2592 - val_f1-score: 0.1821
#
# Epoch 00003: loss improved from 0.87970 to 0.85764, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 4/80
# 169/169 [==============================] - 925s 5s/step - loss: 0.8531 - mean_io_u: 0.4704 - iou_score: 0.1701 - precision: 0.2803 - recall: 0.3073 - f1-score: 0.2580 - val_loss: 0.9387 - val_mean_io_u: 0.4761 - val_iou_score: 0.0959 - val_precision: 0.2099 - val_recall: 0.2364 - val_f1-score: 0.1536
#
# Epoch 00004: loss improved from 0.85764 to 0.84921, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 5/80
# 169/169 [==============================] - 928s 5s/step - loss: 0.8371 - mean_io_u: 0.4703 - iou_score: 0.1796 - precision: 0.2938 - recall: 0.3234 - f1-score: 0.2718 - val_loss: 0.8542 - val_mean_io_u: 0.4704 - val_iou_score: 0.1650 - val_precision: 0.2708 - val_recall: 0.3233 - val_f1-score: 0.2437
#
# Epoch 00005: loss improved from 0.84921 to 0.83489, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 6/80
# 169/169 [==============================] - 929s 6s/step - loss: 0.8277 - mean_io_u: 0.4703 - iou_score: 0.1884 - precision: 0.2996 - recall: 0.3382 - f1-score: 0.2833 - val_loss: 0.8612 - val_mean_io_u: 0.4704 - val_iou_score: 0.1540 - val_precision: 0.2941 - val_recall: 0.2974 - val_f1-score: 0.2340
#
# Epoch 00006: loss improved from 0.83489 to 0.82867, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 7/80
# 169/169 [==============================] - 929s 5s/step - loss: 0.8194 - mean_io_u: 0.4704 - iou_score: 0.1963 - precision: 0.3117 - recall: 0.3396 - f1-score: 0.2930 - val_loss: 0.8735 - val_mean_io_u: 0.4703 - val_iou_score: 0.1501 - val_precision: 0.2935 - val_recall: 0.2965 - val_f1-score: 0.2270
#
# Epoch 00007: loss improved from 0.82867 to 0.81591, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 8/80
# 169/169 [==============================] - 932s 6s/step - loss: 0.8116 - mean_io_u: 0.4703 - iou_score: 0.2000 - precision: 0.3170 - recall: 0.3500 - f1-score: 0.2994 - val_loss: 0.8186 - val_mean_io_u: 0.4705 - val_iou_score: 0.1878 - val_precision: 0.3047 - val_recall: 0.3359 - val_f1-score: 0.2803
#
# Epoch 00008: loss improved from 0.81591 to 0.80985, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 9/80
# 169/169 [==============================] - 932s 6s/step - loss: 0.8047 - mean_io_u: 0.4703 - iou_score: 0.2034 - precision: 0.3216 - recall: 0.3590 - f1-score: 0.3047 - val_loss: 0.8655 - val_mean_io_u: 0.4705 - val_iou_score: 0.1565 - val_precision: 0.2606 - val_recall: 0.3136 - val_f1-score: 0.2336
#
# Epoch 00009: loss improved from 0.80985 to 0.80260, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 10/80
# 169/169 [==============================] - 930s 6s/step - loss: 0.7915 - mean_io_u: 0.4703 - iou_score: 0.2152 - precision: 0.3466 - recall: 0.3756 - f1-score: 0.3206 - val_loss: 0.8086 - val_mean_io_u: 0.4703 - val_iou_score: 0.2011 - val_precision: 0.3282 - val_recall: 0.3267 - val_f1-score: 0.2932
#
# Epoch 00010: loss improved from 0.80260 to 0.79280, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 11/80
# 169/169 [==============================] - 934s 6s/step - loss: 0.7891 - mean_io_u: 0.4703 - iou_score: 0.2179 - precision: 0.3451 - recall: 0.3791 - f1-score: 0.3241 - val_loss: 0.8280 - val_mean_io_u: 0.4703 - val_iou_score: 0.1917 - val_precision: 0.3198 - val_recall: 0.3129 - val_f1-score: 0.2780
#
# Epoch 00011: loss improved from 0.79280 to 0.78576, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 12/80
# 169/169 [==============================] - 933s 6s/step - loss: 0.7879 - mean_io_u: 0.4703 - iou_score: 0.2184 - precision: 0.3464 - recall: 0.3762 - f1-score: 0.3225 - val_loss: 0.8281 - val_mean_io_u: 0.4704 - val_iou_score: 0.1754 - val_precision: 0.3330 - val_recall: 0.3239 - val_f1-score: 0.2589
#
# Epoch 00012: loss did not improve from 0.78576
# Epoch 13/80
# 169/169 [==============================] - 938s 6s/step - loss: 0.7772 - mean_io_u: 0.4704 - iou_score: 0.2264 - precision: 0.3553 - recall: 0.3881 - f1-score: 0.3337 - val_loss: 0.7746 - val_mean_io_u: 0.4704 - val_iou_score: 0.2271 - val_precision: 0.3706 - val_recall: 0.3563 - val_f1-score: 0.3254
#
# Epoch 00013: loss improved from 0.78576 to 0.77361, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 14/80
# 169/169 [==============================] - 941s 6s/step - loss: 0.7673 - mean_io_u: 0.4704 - iou_score: 0.2352 - precision: 0.3656 - recall: 0.3935 - f1-score: 0.3448 - val_loss: 0.7792 - val_mean_io_u: 0.4704 - val_iou_score: 0.2206 - val_precision: 0.3413 - val_recall: 0.3632 - val_f1-score: 0.3212
#
# Epoch 00014: loss improved from 0.77361 to 0.76998, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 15/80
# 169/169 [==============================] - 1022s 6s/step - loss: 0.7612 - mean_io_u: 0.4704 - iou_score: 0.2370 - precision: 0.3663 - recall: 0.3995 - f1-score: 0.3465 - val_loss: 0.7905 - val_mean_io_u: 0.4703 - val_iou_score: 0.2151 - val_precision: 0.3461 - val_recall: 0.3583 - val_f1-score: 0.3130
#
# Epoch 00015: loss improved from 0.76998 to 0.76272, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 16/80
# 169/169 [==============================] - 969s 6s/step - loss: 0.7545 - mean_io_u: 0.4704 - iou_score: 0.2454 - precision: 0.3762 - recall: 0.4049 - f1-score: 0.3554 - val_loss: 0.8014 - val_mean_io_u: 0.4703 - val_iou_score: 0.2016 - val_precision: 0.3352 - val_recall: 0.3332 - val_f1-score: 0.2936
#
# Epoch 00016: loss improved from 0.76272 to 0.75574, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 17/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.7468 - mean_io_u: 0.4704 - iou_score: 0.2507 - precision: 0.3864 - recall: 0.4139 - f1-score: 0.3634 - val_loss: 0.7897 - val_mean_io_u: 0.4705 - val_iou_score: 0.2122 - val_precision: 0.3771 - val_recall: 0.3202 - val_f1-score: 0.3063
#
# Epoch 00017: loss improved from 0.75574 to 0.74733, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 18/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.7520 - mean_io_u: 0.4704 - iou_score: 0.2489 - precision: 0.3892 - recall: 0.4100 - f1-score: 0.3601 - val_loss: 0.8095 - val_mean_io_u: 0.4705 - val_iou_score: 0.2068 - val_precision: 0.3568 - val_recall: 0.3423 - val_f1-score: 0.2954
#
# Epoch 00018: loss did not improve from 0.74733
# Epoch 19/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.7409 - mean_io_u: 0.4705 - iou_score: 0.2579 - precision: 0.3942 - recall: 0.4202 - f1-score: 0.3712 - val_loss: 0.8277 - val_mean_io_u: 0.4709 - val_iou_score: 0.1814 - val_precision: 0.4306 - val_recall: 0.3008 - val_f1-score: 0.2583
#
# Epoch 00019: loss improved from 0.74733 to 0.73787, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 20/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.7413 - mean_io_u: 0.4703 - iou_score: 0.2568 - precision: 0.3966 - recall: 0.4180 - f1-score: 0.3701 - val_loss: 0.8014 - val_mean_io_u: 0.4711 - val_iou_score: 0.2039 - val_precision: 0.3775 - val_recall: 0.3522 - val_f1-score: 0.2929
#
# Epoch 00020: loss did not improve from 0.73787
# Epoch 21/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.7389 - mean_io_u: 0.4704 - iou_score: 0.2615 - precision: 0.3994 - recall: 0.4296 - f1-score: 0.3749 - val_loss: 0.7652 - val_mean_io_u: 0.4704 - val_iou_score: 0.2355 - val_precision: 0.3950 - val_recall: 0.3578 - val_f1-score: 0.3323
#
# Epoch 00021: loss improved from 0.73787 to 0.73124, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 22/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.7304 - mean_io_u: 0.4704 - iou_score: 0.2676 - precision: 0.4074 - recall: 0.4356 - f1-score: 0.3828 - val_loss: 0.8814 - val_mean_io_u: 0.4723 - val_iou_score: 0.1632 - val_precision: 0.3627 - val_recall: 0.2819 - val_f1-score: 0.2430
#
# Epoch 00022: loss did not improve from 0.73124
# Epoch 23/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.7216 - mean_io_u: 0.4704 - iou_score: 0.2708 - precision: 0.4114 - recall: 0.4398 - f1-score: 0.3883 - val_loss: 0.7786 - val_mean_io_u: 0.4706 - val_iou_score: 0.2280 - val_precision: 0.4092 - val_recall: 0.3590 - val_f1-score: 0.3291
#
# Epoch 00023: loss improved from 0.73124 to 0.71946, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 24/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.7174 - mean_io_u: 0.4704 - iou_score: 0.2761 - precision: 0.4206 - recall: 0.4401 - f1-score: 0.3924 - val_loss: 0.7348 - val_mean_io_u: 0.4706 - val_iou_score: 0.2649 - val_precision: 0.3947 - val_recall: 0.4401 - val_f1-score: 0.3749
#
# Epoch 00024: loss did not improve from 0.71946
# Epoch 25/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.7193 - mean_io_u: 0.4704 - iou_score: 0.2760 - precision: 0.4216 - recall: 0.4491 - f1-score: 0.3932 - val_loss: 0.7542 - val_mean_io_u: 0.4708 - val_iou_score: 0.2404 - val_precision: 0.4014 - val_recall: 0.3738 - val_f1-score: 0.3384
#
# Epoch 00025: loss improved from 0.71946 to 0.71449, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 26/80
# 169/169 [==============================] - 959s 6s/step - loss: 0.7069 - mean_io_u: 0.4704 - iou_score: 0.2854 - precision: 0.4312 - recall: 0.4555 - f1-score: 0.4035 - val_loss: 0.7382 - val_mean_io_u: 0.4710 - val_iou_score: 0.2580 - val_precision: 0.3843 - val_recall: 0.4040 - val_f1-score: 0.3634
#
# Epoch 00026: loss improved from 0.71449 to 0.70746, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 27/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.7004 - mean_io_u: 0.4704 - iou_score: 0.2889 - precision: 0.4357 - recall: 0.4580 - f1-score: 0.4082 - val_loss: 0.7951 - val_mean_io_u: 0.4704 - val_iou_score: 0.2084 - val_precision: 0.3695 - val_recall: 0.3309 - val_f1-score: 0.2962
#
# Epoch 00027: loss did not improve from 0.70746
# Epoch 28/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.6993 - mean_io_u: 0.4704 - iou_score: 0.2919 - precision: 0.4357 - recall: 0.4623 - f1-score: 0.4105 - val_loss: 0.7812 - val_mean_io_u: 0.4714 - val_iou_score: 0.2269 - val_precision: 0.4108 - val_recall: 0.3706 - val_f1-score: 0.3273
#
# Epoch 00028: loss improved from 0.70746 to 0.70096, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 29/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.6919 - mean_io_u: 0.4704 - iou_score: 0.2990 - precision: 0.4514 - recall: 0.4725 - f1-score: 0.4210 - val_loss: 0.7434 - val_mean_io_u: 0.4705 - val_iou_score: 0.2598 - val_precision: 0.4179 - val_recall: 0.4058 - val_f1-score: 0.3647
#
# Epoch 00029: loss improved from 0.70096 to 0.69235, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 30/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.6972 - mean_io_u: 0.4704 - iou_score: 0.2957 - precision: 0.4463 - recall: 0.4629 - f1-score: 0.4149 - val_loss: 0.7487 - val_mean_io_u: 0.4711 - val_iou_score: 0.2637 - val_precision: 0.4475 - val_recall: 0.3868 - val_f1-score: 0.3663
#
# Epoch 00030: loss did not improve from 0.69235
# Epoch 31/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.6813 - mean_io_u: 0.4705 - iou_score: 0.3071 - precision: 0.4569 - recall: 0.4768 - f1-score: 0.4296 - val_loss: 0.7478 - val_mean_io_u: 0.4710 - val_iou_score: 0.2468 - val_precision: 0.4457 - val_recall: 0.3821 - val_f1-score: 0.3458
#
# Epoch 00031: loss improved from 0.69235 to 0.68433, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 32/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.6871 - mean_io_u: 0.4704 - iou_score: 0.3061 - precision: 0.4560 - recall: 0.4758 - f1-score: 0.4268 - val_loss: 0.7637 - val_mean_io_u: 0.4703 - val_iou_score: 0.2447 - val_precision: 0.4561 - val_recall: 0.3412 - val_f1-score: 0.3371
#
# Epoch 00032: loss improved from 0.68433 to 0.68369, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 33/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.6817 - mean_io_u: 0.4704 - iou_score: 0.3110 - precision: 0.4636 - recall: 0.4821 - f1-score: 0.4326 - val_loss: 0.7454 - val_mean_io_u: 0.4709 - val_iou_score: 0.2554 - val_precision: 0.4153 - val_recall: 0.4047 - val_f1-score: 0.3626
#
# Epoch 00033: loss did not improve from 0.68369
# Epoch 34/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.6852 - mean_io_u: 0.4705 - iou_score: 0.3081 - precision: 0.4539 - recall: 0.4786 - f1-score: 0.4286 - val_loss: 0.7303 - val_mean_io_u: 0.4707 - val_iou_score: 0.2673 - val_precision: 0.4334 - val_recall: 0.4011 - val_f1-score: 0.3756
#
# Epoch 00034: loss improved from 0.68369 to 0.67816, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 35/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.6627 - mean_io_u: 0.4705 - iou_score: 0.3267 - precision: 0.4771 - recall: 0.5013 - f1-score: 0.4500 - val_loss: 0.7664 - val_mean_io_u: 0.4712 - val_iou_score: 0.2430 - val_precision: 0.4380 - val_recall: 0.3817 - val_f1-score: 0.3409
#
# Epoch 00035: loss improved from 0.67816 to 0.66448, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 36/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.6703 - mean_io_u: 0.4706 - iou_score: 0.3227 - precision: 0.4734 - recall: 0.4968 - f1-score: 0.4437 - val_loss: 0.7472 - val_mean_io_u: 0.4714 - val_iou_score: 0.2697 - val_precision: 0.4603 - val_recall: 0.3909 - val_f1-score: 0.3679
# Epoch 00036: loss did not improve from 0.66448
# Epoch 37/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.6628 - mean_io_u: 0.4706 - iou_score: 0.3249 - precision: 0.4785 - recall: 0.4920 - f1-score: 0.4470 - val_loss: 0.7120 - val_mean_io_u: 0.4707 - val_iou_score: 0.2840 - val_precision: 0.4494 - val_recall: 0.4446 - val_f1-score: 0.3942
#
# Epoch 00037: loss did not improve from 0.66448
# Epoch 38/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.6656 - mean_io_u: 0.4705 - iou_score: 0.3253 - precision: 0.4755 - recall: 0.4965 - f1-score: 0.4480 - val_loss: 0.6763 - val_mean_io_u: 0.4711 - val_iou_score: 0.3077 - val_precision: 0.4935 - val_recall: 0.4577 - val_f1-score: 0.4238
#
# Epoch 00038: loss improved from 0.66448 to 0.66439, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 39/80
# 169/169 [==============================] - 958s 6s/step - loss: 0.6578 - mean_io_u: 0.4706 - iou_score: 0.3339 - precision: 0.4894 - recall: 0.5049 - f1-score: 0.4578 - val_loss: 0.6998 - val_mean_io_u: 0.4708 - val_iou_score: 0.2917 - val_precision: 0.4709 - val_recall: 0.4163 - val_f1-score: 0.4029
#
# Epoch 00039: loss improved from 0.66439 to 0.66060, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 40/80
# 169/169 [==============================] - 957s 6s/step - loss: 0.6608 - mean_io_u: 0.4706 - iou_score: 0.3290 - precision: 0.4844 - recall: 0.5019 - f1-score: 0.4526 - val_loss: 0.7069 - val_mean_io_u: 0.4711 - val_iou_score: 0.2876 - val_precision: 0.4849 - val_recall: 0.4319 - val_f1-score: 0.4017
#
# Epoch 00040: loss did not improve from 0.66060
# Epoch 41/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.6532 - mean_io_u: 0.4706 - iou_score: 0.3375 - precision: 0.4936 - recall: 0.5096 - f1-score: 0.4618 - val_loss: 0.7207 - val_mean_io_u: 0.4708 - val_iou_score: 0.2800 - val_precision: 0.5225 - val_recall: 0.3838 - val_f1-score: 0.3787
#
# Epoch 00041: loss improved from 0.66060 to 0.64351, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 42/80
# 169/169 [==============================] - 959s 6s/step - loss: 0.6576 - mean_io_u: 0.4707 - iou_score: 0.3349 - precision: 0.4864 - recall: 0.5042 - f1-score: 0.4571 - val_loss: 0.8093 - val_mean_io_u: 0.4717 - val_iou_score: 0.2204 - val_precision: 0.4157 - val_recall: 0.3758 - val_f1-score: 0.3080
#
# Epoch 00042: loss did not improve from 0.64351
# Epoch 43/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.6475 - mean_io_u: 0.4706 - iou_score: 0.3416 - precision: 0.4938 - recall: 0.5142 - f1-score: 0.4648 - val_loss: 0.7122 - val_mean_io_u: 0.4706 - val_iou_score: 0.2817 - val_precision: 0.4991 - val_recall: 0.3920 - val_f1-score: 0.3860
#
# Epoch 00043: loss improved from 0.64351 to 0.64351, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 44/80
# 169/169 [==============================] - 958s 6s/step - loss: 0.6333 - mean_io_u: 0.4707 - iou_score: 0.3544 - precision: 0.5078 - recall: 0.5348 - f1-score: 0.4793 - val_loss: 0.6827 - val_mean_io_u: 0.4713 - val_iou_score: 0.3094 - val_precision: 0.5048 - val_recall: 0.4430 - val_f1-score: 0.4235
#
# Epoch 00044: loss improved from 0.64351 to 0.63552, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 45/80
# 169/169 [==============================] - 959s 6s/step - loss: 0.6359 - mean_io_u: 0.4708 - iou_score: 0.3510 - precision: 0.5072 - recall: 0.5222 - f1-score: 0.4763 - val_loss: 0.7063 - val_mean_io_u: 0.4707 - val_iou_score: 0.2839 - val_precision: 0.5115 - val_recall: 0.4044 - val_f1-score: 0.3900
#
# Epoch 00045: loss did not improve from 0.63552
# Epoch 46/80
# 169/169 [==============================] - 957s 6s/step - loss: 0.6360 - mean_io_u: 0.4708 - iou_score: 0.3535 - precision: 0.5097 - recall: 0.5175 - f1-score: 0.4770 - val_loss: 0.6960 - val_mean_io_u: 0.4711 - val_iou_score: 0.2984 - val_precision: 0.4967 - val_recall: 0.4190 - val_f1-score: 0.4077
#
# Epoch 00046: loss improved from 0.63552 to 0.63541, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 47/80
# 169/169 [==============================] - 959s 6s/step - loss: 0.6247 - mean_io_u: 0.4710 - iou_score: 0.3598 - precision: 0.5210 - recall: 0.5271 - f1-score: 0.4853 - val_loss: 0.7464 - val_mean_io_u: 0.4706 - val_iou_score: 0.2597 - val_precision: 0.4600 - val_recall: 0.3793 - val_f1-score: 0.3637
#
# Epoch 00047: loss improved from 0.63541 to 0.62613, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 48/80
# 169/169 [==============================] - 959s 6s/step - loss: 0.6327 - mean_io_u: 0.4709 - iou_score: 0.3553 - precision: 0.5122 - recall: 0.5265 - f1-score: 0.4795 - val_loss: 0.7059 - val_mean_io_u: 0.4710 - val_iou_score: 0.2970 - val_precision: 0.5374 - val_recall: 0.4374 - val_f1-score: 0.4017
#
# Epoch 00048: loss did not improve from 0.62613
# Epoch 49/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.6261 - mean_io_u: 0.4709 - iou_score: 0.3614 - precision: 0.5186 - recall: 0.5308 - f1-score: 0.4864 - val_loss: 0.6521 - val_mean_io_u: 0.4738 - val_iou_score: 0.3280 - val_precision: 0.4658 - val_recall: 0.5166 - val_f1-score: 0.4496
#
# Epoch 00049: loss improved from 0.62613 to 0.62359, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 50/80
# 169/169 [==============================] - 958s 6s/step - loss: 0.6103 - mean_io_u: 0.4709 - iou_score: 0.3738 - precision: 0.5277 - recall: 0.5416 - f1-score: 0.4993 - val_loss: 0.7142 - val_mean_io_u: 0.4727 - val_iou_score: 0.2859 - val_precision: 0.5356 - val_recall: 0.3987 - val_f1-score: 0.3893
#
# Epoch 00050: loss improved from 0.62359 to 0.61123, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 51/80
# 169/169 [==============================] - 959s 6s/step - loss: 0.6116 - mean_io_u: 0.4709 - iou_score: 0.3742 - precision: 0.5335 - recall: 0.5412 - f1-score: 0.4993 - val_loss: 0.6732 - val_mean_io_u: 0.4707 - val_iou_score: 0.3189 - val_precision: 0.5299 - val_recall: 0.4419 - val_f1-score: 0.4321
#
# Epoch 00051: loss did not improve from 0.61123
# Epoch 52/80
# 169/169 [==============================] - 959s 6s/step - loss: 0.6091 - mean_io_u: 0.4709 - iou_score: 0.3748 - precision: 0.5357 - recall: 0.5431 - f1-score: 0.5006 - val_loss: 0.6507 - val_mean_io_u: 0.4711 - val_iou_score: 0.3321 - val_precision: 0.5401 - val_recall: 0.4574 - val_f1-score: 0.4487
#
# Epoch 00052: loss improved from 0.61123 to 0.61030, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 53/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.6058 - mean_io_u: 0.4709 - iou_score: 0.3773 - precision: 0.5411 - recall: 0.5517 - f1-score: 0.5047 - val_loss: 0.6218 - val_mean_io_u: 0.4721 - val_iou_score: 0.3724 - val_precision: 0.5582 - val_recall: 0.4922 - val_f1-score: 0.4869
#
# Epoch 00053: loss improved from 0.61030 to 0.60322, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 54/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.6128 - mean_io_u: 0.4709 - iou_score: 0.3738 - precision: 0.5309 - recall: 0.5447 - f1-score: 0.4984 - val_loss: 0.7352 - val_mean_io_u: 0.4716 - val_iou_score: 0.2520 - val_precision: 0.4602 - val_recall: 0.4361 - val_f1-score: 0.3524
#
# Epoch 00054: loss did not improve from 0.60322
# Epoch 55/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.6012 - mean_io_u: 0.4711 - iou_score: 0.3808 - precision: 0.5399 - recall: 0.5485 - f1-score: 0.5072 - val_loss: 0.6522 - val_mean_io_u: 0.4725 - val_iou_score: 0.3334 - val_precision: 0.5316 - val_recall: 0.4637 - val_f1-score: 0.4461
#
# Epoch 00055: loss did not improve from 0.60322
# Epoch 56/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.6058 - mean_io_u: 0.4712 - iou_score: 0.3762 - precision: 0.5343 - recall: 0.5439 - f1-score: 0.5038 - val_loss: 0.6667 - val_mean_io_u: 0.4721 - val_iou_score: 0.3113 - val_precision: 0.4954 - val_recall: 0.4538 - val_f1-score: 0.4211
#
# Epoch 00056: loss did not improve from 0.60322
# Epoch 57/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.6015 - mean_io_u: 0.4709 - iou_score: 0.3838 - precision: 0.5403 - recall: 0.5517 - f1-score: 0.5088 - val_loss: 0.6553 - val_mean_io_u: 0.4712 - val_iou_score: 0.3357 - val_precision: 0.5554 - val_recall: 0.4579 - val_f1-score: 0.4419
#
# Epoch 00057: loss improved from 0.60322 to 0.59928, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 58/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.5965 - mean_io_u: 0.4712 - iou_score: 0.3884 - precision: 0.5463 - recall: 0.5516 - f1-score: 0.5136 - val_loss: 0.6132 - val_mean_io_u: 0.4715 - val_iou_score: 0.3647 - val_precision: 0.5620 - val_recall: 0.4848 - val_f1-score: 0.4832
#
# Epoch 00058: loss improved from 0.59928 to 0.59683, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 59/80
# 169/169 [==============================] - 1014s 6s/step - loss: 0.5947 - mean_io_u: 0.4711 - iou_score: 0.3890 - precision: 0.5455 - recall: 0.5675 - f1-score: 0.5147 - val_loss: 0.6209 - val_mean_io_u: 0.4713 - val_iou_score: 0.3645 - val_precision: 0.6103 - val_recall: 0.4567 - val_f1-score: 0.4813
#
# Epoch 00059: loss improved from 0.59683 to 0.58860, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 60/80
# 169/169 [==============================] - 1007s 6s/step - loss: 0.5932 - mean_io_u: 0.4713 - iou_score: 0.3932 - precision: 0.5500 - recall: 0.5667 - f1-score: 0.5192 - val_loss: 0.6397 - val_mean_io_u: 0.4721 - val_iou_score: 0.3578 - val_precision: 0.5797 - val_recall: 0.4964 - val_f1-score: 0.4758
#
# Epoch 00060: loss did not improve from 0.58860
# Epoch 61/80
# 169/169 [==============================] - 970s 6s/step - loss: 0.5847 - mean_io_u: 0.4711 - iou_score: 0.4029 - precision: 0.5590 - recall: 0.5703 - f1-score: 0.5277 - val_loss: 0.6203 - val_mean_io_u: 0.4713 - val_iou_score: 0.3612 - val_precision: 0.5804 - val_recall: 0.4730 - val_f1-score: 0.4707
#
# Epoch 00061: loss improved from 0.58860 to 0.58277, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 62/80
# 169/169 [==============================] - 974s 6s/step - loss: 0.5813 - mean_io_u: 0.4713 - iou_score: 0.4020 - precision: 0.5655 - recall: 0.5628 - f1-score: 0.5288 - val_loss: 0.6483 - val_mean_io_u: 0.4720 - val_iou_score: 0.3323 - val_precision: 0.5968 - val_recall: 0.4329 - val_f1-score: 0.4398
#
# Epoch 00062: loss improved from 0.58277 to 0.58130, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 63/80
# 169/169 [==============================] - 993s 6s/step - loss: 0.5676 - mean_io_u: 0.4712 - iou_score: 0.4115 - precision: 0.5740 - recall: 0.5734 - f1-score: 0.5378 - val_loss: 0.6572 - val_mean_io_u: 0.4723 - val_iou_score: 0.3231 - val_precision: 0.5132 - val_recall: 0.4545 - val_f1-score: 0.4320
#
# Epoch 00063: loss improved from 0.58130 to 0.57960, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 64/80
# 169/169 [==============================] - 998s 6s/step - loss: 0.5853 - mean_io_u: 0.4713 - iou_score: 0.3978 - precision: 0.5550 - recall: 0.5658 - f1-score: 0.5239 - val_loss: 0.6450 - val_mean_io_u: 0.4748 - val_iou_score: 0.3491 - val_precision: 0.5366 - val_recall: 0.4737 - val_f1-score: 0.4620
#
# Epoch 00064: loss did not improve from 0.57960
# Epoch 65/80
# 169/169 [==============================] - 1008s 6s/step - loss: 0.5719 - mean_io_u: 0.4713 - iou_score: 0.4094 - precision: 0.5647 - recall: 0.5846 - f1-score: 0.5368 - val_loss: 0.6239 - val_mean_io_u: 0.4718 - val_iou_score: 0.3580 - val_precision: 0.5464 - val_recall: 0.5271 - val_f1-score: 0.4817
#
# Epoch 00065: loss improved from 0.57960 to 0.57492, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 66/80
# 169/169 [==============================] - 997s 6s/step - loss: 0.5769 - mean_io_u: 0.4713 - iou_score: 0.4102 - precision: 0.5648 - recall: 0.5775 - f1-score: 0.5346 - val_loss: 0.6708 - val_mean_io_u: 0.4719 - val_iou_score: 0.3180 - val_precision: 0.5617 - val_recall: 0.4556 - val_f1-score: 0.4248
#
# Epoch 00066: loss did not improve from 0.57492
# Epoch 67/80
# 169/169 [==============================] - 1072s 6s/step - loss: 0.5611 - mean_io_u: 0.4712 - iou_score: 0.4196 - precision: 0.5745 - recall: 0.5850 - f1-score: 0.5460 - val_loss: 0.6591 - val_mean_io_u: 0.4710 - val_iou_score: 0.3345 - val_precision: 0.5619 - val_recall: 0.4533 - val_f1-score: 0.4365
#
# Epoch 00067: loss improved from 0.57492 to 0.56758, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 68/80
# 169/169 [==============================] - 1017s 6s/step - loss: 0.5636 - mean_io_u: 0.4711 - iou_score: 0.4151 - precision: 0.5752 - recall: 0.5784 - f1-score: 0.5416 - val_loss: 0.6043 - val_mean_io_u: 0.4721 - val_iou_score: 0.3684 - val_precision: 0.5923 - val_recall: 0.4939 - val_f1-score: 0.4854
#
# Epoch 00068: loss did not improve from 0.56758
# Epoch 69/80
# 169/169 [==============================] - 972s 6s/step - loss: 0.5698 - mean_io_u: 0.4712 - iou_score: 0.4154 - precision: 0.5718 - recall: 0.5801 - f1-score: 0.5400 - val_loss: 0.6338 - val_mean_io_u: 0.4718 - val_iou_score: 0.3553 - val_precision: 0.5293 - val_recall: 0.4822 - val_f1-score: 0.4674
#
# Epoch 00069: loss did not improve from 0.56758
# Epoch 70/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.5638 - mean_io_u: 0.4712 - iou_score: 0.4205 - precision: 0.5773 - recall: 0.5868 - f1-score: 0.5459 - val_loss: 0.6581 - val_mean_io_u: 0.4714 - val_iou_score: 0.3372 - val_precision: 0.6018 - val_recall: 0.4316 - val_f1-score: 0.4421
#
# Epoch 00070: loss improved from 0.56758 to 0.56508, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 71/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.5508 - mean_io_u: 0.4713 - iou_score: 0.4297 - precision: 0.5922 - recall: 0.5950 - f1-score: 0.5572 - val_loss: 0.5879 - val_mean_io_u: 0.4728 - val_iou_score: 0.3933 - val_precision: 0.5947 - val_recall: 0.5247 - val_f1-score: 0.5176
#
# Epoch 00071: loss improved from 0.56508 to 0.56116, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 72/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.5641 - mean_io_u: 0.4711 - iou_score: 0.4206 - precision: 0.5736 - recall: 0.5902 - f1-score: 0.5452 - val_loss: 0.6011 - val_mean_io_u: 0.4721 - val_iou_score: 0.3751 - val_precision: 0.5419 - val_recall: 0.5610 - val_f1-score: 0.4983
#
# Epoch 00072: loss did not improve from 0.56116
# Epoch 73/80
# 169/169 [==============================] - 976s 6s/step - loss: 0.5637 - mean_io_u: 0.4711 - iou_score: 0.4178 - precision: 0.5747 - recall: 0.5879 - f1-score: 0.5424 - val_loss: 0.6234 - val_mean_io_u: 0.4729 - val_iou_score: 0.3635 - val_precision: 0.5494 - val_recall: 0.5002 - val_f1-score: 0.4778
#
# Epoch 00073: loss did not improve from 0.56116
# Epoch 74/80
# 169/169 [==============================] - 966s 6s/step - loss: 0.5507 - mean_io_u: 0.4712 - iou_score: 0.4299 - precision: 0.5885 - recall: 0.5960 - f1-score: 0.5564 - val_loss: 0.6277 - val_mean_io_u: 0.4725 - val_iou_score: 0.3624 - val_precision: 0.5983 - val_recall: 0.4944 - val_f1-score: 0.4759
#
# Epoch 00074: loss did not improve from 0.56116
# Epoch 75/80
# 169/169 [==============================] - 980s 6s/step - loss: 0.5719 - mean_io_u: 0.4712 - iou_score: 0.4142 - precision: 0.5721 - recall: 0.5825 - f1-score: 0.5386 - val_loss: 0.6527 - val_mean_io_u: 0.4734 - val_iou_score: 0.3422 - val_precision: 0.5519 - val_recall: 0.4523 - val_f1-score: 0.4494
#
# Epoch 00075: loss did not improve from 0.56116
# Epoch 76/80
# 169/169 [==============================] - 1030s 6s/step - loss: 0.5577 - mean_io_u: 0.4713 - iou_score: 0.4244 - precision: 0.5847 - recall: 0.5890 - f1-score: 0.5510 - val_loss: 0.6201 - val_mean_io_u: 0.4712 - val_iou_score: 0.3564 - val_precision: 0.5935 - val_recall: 0.4687 - val_f1-score: 0.4698
#
# Epoch 00076: loss improved from 0.56116 to 0.55925, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 77/80
# 169/169 [==============================] - 1003s 6s/step - loss: 0.5575 - mean_io_u: 0.4713 - iou_score: 0.4271 - precision: 0.5835 - recall: 0.5906 - f1-score: 0.5523 - val_loss: 0.5925 - val_mean_io_u: 0.4723 - val_iou_score: 0.3873 - val_precision: 0.5873 - val_recall: 0.5248 - val_f1-score: 0.5072
#
# Epoch 00077: loss improved from 0.55925 to 0.54936, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 78/80
# 169/169 [==============================] - 1036s 6s/step - loss: 0.5537 - mean_io_u: 0.4712 - iou_score: 0.4321 - precision: 0.5865 - recall: 0.5971 - f1-score: 0.5567 - val_loss: 0.6293 - val_mean_io_u: 0.4724 - val_iou_score: 0.3718 - val_precision: 0.5987 - val_recall: 0.5057 - val_f1-score: 0.4871
#
# Epoch 00078: loss did not improve from 0.54936
# Epoch 79/80
# 169/169 [==============================] - 1020s 6s/step - loss: 0.5533 - mean_io_u: 0.4709 - iou_score: 0.4303 - precision: 0.5870 - recall: 0.5939 - f1-score: 0.5557 - val_loss: 0.6059 - val_mean_io_u: 0.4725 - val_iou_score: 0.3757 - val_precision: 0.5860 - val_recall: 0.4972 - val_f1-score: 0.4850
#
# Epoch 00079: loss improved from 0.54936 to 0.54913, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5
# Epoch 80/80
# 169/169 [==============================] - 973s 6s/step - loss: 0.5500 - mean_io_u: 0.4713 - iou_score: 0.4320 - precision: 0.5910 - recall: 0.6020 - f1-score: 0.5581 - val_loss: 0.5740 - val_mean_io_u: 0.4737 - val_iou_score: 0.4075 - val_precision: 0.5998 - val_recall: 0.5445 - val_f1-score: 0.5250
#
# Epoch 00080: loss improved from 0.54913 to 0.54355, saving model to model\food_segmentation_80_epochs_softmax_cat_focal_dice_loss_128_class_weights_adam_32_filters_20210610-173226.h5

# %% [markdown]
# ### History of the training
# Plot metrics evolution from 0 to 80 epoch during the training

# %%
import matplotlib.pyplot as plt
def plot_history(model_history, keys, labels=("epochs", "metrics"), figsize=(10,5)):
    
    fig = plt.figure(figsize=figsize)
    
    # take all pairs of training and val metrics
    for i in range(0, len(keys), 2):
        m, val_m = keys[i], keys[i+1]
        
        plt.plot(model_history.history[m])
        plt.plot(model_history.history[val_m])
        
    plt.xlabel(labels[0])
    plt.ylabel(labels[1])

    # Adding legend
    plt.legend(keys,
          title ="Legend",
          loc ="upper left",
          bbox_to_anchor =(1.0, 0, 0.5, 1))
    plt.title("Training history")
    plt.grid(True)
    plt.show()

# %%
# plot history
plot_history(history,['loss','val_loss'], labels=("epochs", "loss"), figsize=(15,7))
plot_history(history,['iou_score','val_iou_score', 'precision', 'val_precision', 'recall', 'val_recall'], figsize=(15,7))

# %% [markdown]
# Store model and history on files

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_C.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pandas as pd

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open("train_history_model_C.csv", mode="w") as file:
    hist_df.to_csv(file)
